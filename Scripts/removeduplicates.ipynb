# %%
import os
import json
import shutil
import hashlib
from pathlib import Path
from typing import Dict, List, Set
import re

class SongConsolidator:
    def __init__(self, base_songs_folder: str, output_folder: str = "consolidated_songs"):
        self.base_songs_folder = Path(base_songs_folder)
        self.output_folder = Path(output_folder)
        self.songs_output = self.output_folder / "songs"
        self.metadata_output = self.output_folder / "metadata"
        
        # Create output directories
        self.songs_output.mkdir(parents=True, exist_ok=True)
        self.metadata_output.mkdir(parents=True, exist_ok=True)
        
        # Data structures to track songs and playlists
        self.unique_songs = {}  # track_uri -> song_info
        self.playlist_data = {}  # playlist_name -> playlist_info
        self.song_to_playlists = {}  # song_id -> list of playlist names
        
    def generate_song_id(self, track_name: str, artists: str) -> str:
        """Generate a unique ID for a song based on track name and artists"""
        # Clean the string for ID generation
        clean_string = f"{track_name}_{artists}".lower()
        clean_string = re.sub(r'[^a-z0-9_]', '', clean_string)
        
        # Generate a hash for uniqueness
        hash_object = hashlib.md5(clean_string.encode())
        return f"song_{hash_object.hexdigest()[:12]}"
    
    def normalize_filename(self, filename: str) -> str:
        """Normalize filename for comparison"""
        return filename.lower().replace('-', '').replace('_', '').replace(' ', '')
    
    def is_duplicate_song(self, song1: dict, song2: dict) -> bool:
        """Check if two songs are duplicates based on metadata"""
        # Primary check: Spotify URI
        if song1.get('track_uri') and song2.get('track_uri'):
            return song1['track_uri'] == song2['track_uri']
        
        # Secondary check: Track name and artists
        name1 = song1.get('track_name', '').lower().strip()
        name2 = song2.get('track_name', '').lower().strip()
        
        artists1 = song1.get('artists_string', '').lower().strip()
        artists2 = song2.get('artists_string', '').lower().strip()
        
        return name1 == name2 and artists1 == artists2
    
    def find_song_files(self, playlist_folder: Path) -> List[Path]:
        """Find all audio files in a playlist folder"""
        audio_extensions = {'.mp3', '.webm', '.wav', '.flac', '.m4a'}
        song_files = []
        
        for file_path in playlist_folder.iterdir():
            if file_path.is_file() and file_path.suffix.lower() in audio_extensions:
                song_files.append(file_path)
        
        return song_files
    
    def process_playlist_folder(self, playlist_folder: Path):
        """Process a single playlist folder"""
        playlist_name = playlist_folder.name
        json_file = playlist_folder / "enhanced_download_summary.json"
        
        # Skip folders without the JSON file
        if not json_file.exists():
            print(f"Skipping {playlist_name}: No enhanced_download_summary.json found")
            return
        
        print(f"Processing playlist: {playlist_name}")
        
        try:
            with open(json_file, 'r', encoding='utf-8') as f:
                data = json.load(f)
        except Exception as e:
            print(f"Error reading JSON from {playlist_name}: {e}")
            return
        
        # Store playlist metadata
        download_info = data.get('download_info', {})
        self.playlist_data[playlist_name] = {
            'name': playlist_name,
            'total_tracks': download_info.get('total_tracks', 0),
            'successful_downloads': download_info.get('successful_downloads', 0),
            'source_url': download_info.get('source_url', ''),
            'timestamp': download_info.get('timestamp', ''),
            'folder_path': str(playlist_folder)
        }
        
        # Get all song files in the folder
        song_files = self.find_song_files(playlist_folder)
        
        # Process each song in the download results
        download_results = data.get('download_results', [])
        
        for result in download_results:
            if result.get('status') != 'success':
                continue
                
            metadata = result.get('metadata', {})
            filename = result.get('filename', '')
            
            # Find the actual file
            matching_file = None
            for song_file in song_files:
                if self.normalize_filename(song_file.name) == self.normalize_filename(filename):
                    matching_file = song_file
                    break
            
            if not matching_file:
                print(f"Warning: Could not find file {filename} in {playlist_name}")
                continue
            
            # Check if this song already exists
            track_uri = metadata.get('track_uri', '')
            song_id = None
            is_duplicate = False
            
            # Look for existing song
            for existing_uri, existing_song in self.unique_songs.items():
                if self.is_duplicate_song(metadata, existing_song['metadata']):
                    song_id = existing_song['song_id']
                    is_duplicate = True
                    break
            
            # If not a duplicate, create new entry
            if not is_duplicate:
                song_id = self.generate_song_id(
                    metadata.get('track_name', ''),
                    metadata.get('artists_string', '')
                )
                
                # Copy the song file to consolidated folder
                file_extension = matching_file.suffix
                new_filename = f"{song_id}{file_extension}"
                new_file_path = self.songs_output / new_filename
                
                try:
                    shutil.copy2(matching_file, new_file_path)
                    print(f"Copied: {filename} -> {new_filename}")
                except Exception as e:
                    print(f"Error copying {filename}: {e}")
                    continue
                
                # Store song info
                self.unique_songs[track_uri or song_id] = {
                    'song_id': song_id,
                    'filename': new_filename,
                    'original_filename': filename,
                    'file_path': str(new_file_path),
                    'metadata': metadata,
                    'playlists': [playlist_name]
                }
                
                self.song_to_playlists[song_id] = [playlist_name]
            else:
                # Add this playlist to existing song
                if playlist_name not in self.unique_songs[track_uri or song_id]['playlists']:
                    self.unique_songs[track_uri or song_id]['playlists'].append(playlist_name)
                
                if song_id not in self.song_to_playlists:
                    self.song_to_playlists[song_id] = []
                if playlist_name not in self.song_to_playlists[song_id]:
                    self.song_to_playlists[song_id].append(playlist_name)
                
                print(f"Duplicate found: {filename} (already exists as {song_id})")
    
    def save_metadata(self):
        """Save consolidated metadata to JSON files"""
        
        # Save song database
        songs_db = {
            'songs': {},
            'stats': {
                'total_unique_songs': len(self.unique_songs),
                'total_playlists': len(self.playlist_data),
                'generated_at': __import__('datetime').datetime.now().isoformat()
            }
        }
        
        for song_key, song_info in self.unique_songs.items():
            song_id = song_info['song_id']
            songs_db['songs'][song_id] = song_info
        
        with open(self.metadata_output / 'songs_database.json', 'w', encoding='utf-8') as f:
            json.dump(songs_db, f, indent=2, ensure_ascii=False)
        
        # Save playlist database
        playlists_db = {
            'playlists': self.playlist_data,
            'stats': {
                'total_playlists': len(self.playlist_data),
                'generated_at': __import__('datetime').datetime.now().isoformat()
            }
        }
        
        for playlist_name, playlist_info in self.playlist_data.items():
            # Add songs in this playlist
            playlist_songs = []
            for song_id, playlists in self.song_to_playlists.items():
                if playlist_name in playlists:
                    playlist_songs.append(song_id)
            playlist_info['songs'] = playlist_songs
            playlist_info['unique_song_count'] = len(playlist_songs)
        
        with open(self.metadata_output / 'playlists_database.json', 'w', encoding='utf-8') as f:
            json.dump(playlists_db, f, indent=2, ensure_ascii=False)
        
        # Save song-to-playlist mapping
        mapping_db = {
            'song_to_playlists': self.song_to_playlists,
            'stats': {
                'total_mappings': len(self.song_to_playlists),
                'generated_at': __import__('datetime').datetime.now().isoformat()
            }
        }
        
        with open(self.metadata_output / 'song_playlist_mapping.json', 'w', encoding='utf-8') as f:
            json.dump(mapping_db, f, indent=2, ensure_ascii=False)
    
    def run(self):
        """Run the consolidation process"""
        print(f"Starting consolidation process...")
        print(f"Base folder: {self.base_songs_folder}")
        print(f"Output folder: {self.output_folder}")
        
        if not self.base_songs_folder.exists():
            print(f"Error: Base songs folder '{self.base_songs_folder}' does not exist!")
            return
        
        # Process each playlist folder
        playlist_folders = [f for f in self.base_songs_folder.iterdir() if f.is_dir()]
        
        if not playlist_folders:
            print("No playlist folders found!")
            return
        
        print(f"Found {len(playlist_folders)} playlist folders")
        
        for playlist_folder in playlist_folders:
            self.process_playlist_folder(playlist_folder)
        
        # Save all metadata
        self.save_metadata()
        
        # Print summary
        print("\n" + "="*50)
        print("CONSOLIDATION COMPLETE")
        print("="*50)
        print(f"Total unique songs: {len(self.unique_songs)}")
        print(f"Total playlists processed: {len(self.playlist_data)}")
        print(f"Songs saved to: {self.songs_output}")
        print(f"Metadata saved to: {self.metadata_output}")
        
        # Show duplicate statistics
        total_occurrences = sum(len(song_info['playlists']) for song_info in self.unique_songs.values())
        duplicates_avoided = total_occurrences - len(self.unique_songs)
        print(f"Duplicates avoided: {duplicates_avoided}")
        
        print("\nGenerated files:")
        print("- songs_database.json (complete song information)")
        print("- playlists_database.json (playlist information with song lists)")
        print("- song_playlist_mapping.json (song to playlist relationships)")


def main():
    # Configuration
    SONGS_FOLDER = "songs"  # Your base songs folder
    OUTPUT_FOLDER = "consolidated_music"  # Output folder name
    
    # Create and run consolidator
    consolidator = SongConsolidator(SONGS_FOLDER, OUTPUT_FOLDER)
    consolidator.run()


if __name__ == "__main__":
    main()
# Out:
# Starting consolidation process...
# Base folder: songs
# Output folder: consolidated_music
# Found 11 playlist folders
# Processing playlist: All in one
# Copied: Hold-Me-Now-Yuvan-Shankar-Raja-Sanjith-Hegde-Thurga.mp3 -> song_06ffdb5ab169.mp3
# Copied: Kanne-Kanne-Madras-Gig-Leon-James-Jonita-Gandhi.mp3 -> song_d0fb39333ab3.mp3
# Copied: High-On-Love-Yuvan-Shankar-Raja.mp3 -> song_cbcc73d7e617.mp3
# Copied: Vilambara-Idaiveli-From-Imaikkaa-Nodigal-Hiphop-Tamizha-Christopher-Stanley-Sudarshan-Ashok-Srinisha.mp3 -> song_47b89f5754c9.mp3
# Copied: Vaadi-Pulla-Vaadi-Hiphop-Tamizha.mp3 -> song_2937d1e0634a.mp3
# Copied: Thangamey-Anirudh-Ravichander.mp3 -> song_b1eed02e084e.mp3
# Copied: Oh-Penne-Anirudh-Ravichander-Vishal-Dadlani.mp3 -> song_afd87a393b33.mp3
# Copied: Kannala-Kannala-The-Melting-Point-of-Love-Hiphop-Tamizha-Kaushik-Krish-Padmalatha.mp3 -> song_1600ddfc5d9c.mp3
# Copied: Idhazhin-Oram-The-Innocence-of-Love-Anirudh-Ravichander-Ajesh.mp3 -> song_f904bcb561f8.mp3
# Copied: Po-Nee-Po-The-Pain-of-Love-Anirudh-Ravichander-Mohit-Chauhan.mp3 -> song_ad432bc3905d.mp3
# Copied: Kannazhaga-The-Kiss-of-Love-Anirudh-Ravichander-Dhanush-Shruti-Haasan.mp3 -> song_16381ebdfa4f.mp3
# Copied: Nee-Paartha-Vizhigal-The-Touch-of-Love-Anirudh-Ravichander-Vijay-Yesudas-Shweta-Mohan.mp3 -> song_b0c033d9237c.mp3
# Copied: Kanave-Kanave-Anirudh-Ravichander.mp3 -> song_3cd1ee8dc7bd.mp3
# Copied: Pookkal-Pookkum-G-V-Prakash-Roop-Kumar-Rathod-Harini-Andrea-Jeremiah.mp3 -> song_87179519bee4.mp3
# Copied: Nenjukkul-Peidhidum-Harris-Jayaraj-Hariharan-Devan-Ekambaram-VV-Prassanna.mp3 -> song_a36025857866.mp3
# Copied: Mundhinam-Harris-Jayaraj-Naresh-Iyer-Prashanthini.mp3 -> song_e65353861716.mp3
# Copied: Annul-Maelae-Harris-Jayaraj-Sudha-Ragunathan.mp3 -> song_501009bef4b4.mp3
# Copied: Mannipaaya-AR-Rahman-Shreya-Ghoshal.mp3 -> song_3edf6846cf1f.mp3
# Copied: Ennavale-Adi-Ennavale-From-Kaadhalan-Unnikrishnan.mp3 -> song_d47d21ddbe23.mp3
# Copied: New-York-AR-Rahman.mp3 -> song_78e5b41b64c4.mp3
# Copied: Anbil-Avan-AR-Rahman-Chinmayi-Devan-Ekambaram.mp3 -> song_1f536bba5b5a.mp3
# Copied: The-Life-of-Ram-Govind-Vasantha-Pradeep-Kumar.mp3 -> song_6981c94d29af.mp3
# Copied: Mental-Manadhil-AR-Rahman-Jonita-Gandhi.mp3 -> song_c2f35f1007ed.mp3
# Copied: Marudaani-AR-Rahman-Madhushree-Hentry-Kuruvila.mp3 -> song_866113083449.mp3
# Copied: Kaara-Aattakkaara-AR-Rahman-Aaryan-Dinesh-Kanagaratnam-Darshana-KT-Shashaa-Tirupati.mp3 -> song_9b13d3f66f26.mp3
# Copied: Mazhai-Vara-Pogudhae-Harris-Jayaraj-Karthik-Emcee-Jesz.mp3 -> song_8d5d404ba43a.mp3
# Copied: Engeyum-Kaadhal-Harris-Jayaraj-Aalaap-Raju-Devan-Ekambaram-Ranina-Reddy.mp3 -> song_1a2a1ba9e0f2.mp3
# Copied: Aye-Sinamika-AR-Rahman-Karthik.mp3 -> song_3b56538d08cf.mp3
# Copied: Neeyum-Naanum-Anirudh-Ravichander-and-Neeti-Mohan.mp3 -> song_8dee254c59c0.mp3
# Copied: Visiri-Darbuka-Siva-Sid-Sriram-Shashaa-Tirupati.mp3 -> song_6703e654a341.mp3
# Copied: Kannaana-Kanne-Anirudh-RavichanderSean-Roldan.mp3 -> song_376a775df7fb.mp3
# Copied: Oh-Oh-The-First-Love-of-Tamizh-Anirudh-Ravichander-Dhanush-Nikhita-Gandhi.mp3 -> song_72d81830b452.mp3
# Copied: Kadhal-Aasai-From-Anjaan-Yuvan-Shankar-Raja-Sooraj-Santhosh.mp3 -> song_d13872233edb.mp3
# Copied: Idhayathai-Yedho-Ondru-Harris-Jayaraj-Chinmayi.mp3 -> song_b7a757592eca.mp3
# Copied: Un-Vizhigalil-Anirudh-Ravichander-Shruti-Haasan.mp3 -> song_3afbd2b96bc9.mp3
# Copied: Mazhai-Kuruvi-AR-Rahman.mp3 -> song_33e14a6d3571.mp3
# Copied: Ennadi-Maayavi-Nee-Sid-Sriram.mp3 -> song_cb7a20a7b7ae.mp3
# Copied: Nee-Kavithaigala-From-Maragatha-Naanayam-Dhibu-Ninan-Thomas-Pradeep-Kumar.mp3 -> song_50164e6093f4.mp3
# Copied: Mental-Manadhil-Female-AR-Rahman-Jonita-Gandhi.mp3 -> song_77c93d6e1d44.mp3
# Copied: Sirikkadhey-Anirudh-Ravichander-Arjun-Kanungo-Srinidhi-Venkatesh.mp3 -> song_b918488b33d0.mp3
# Copied: Senjitaley-Anirudh-Ravichander.mp3 -> song_1c4d58312cba.mp3
# Copied: Sirukki-Vaasam-Santhosh-Narayanan-Anand-Aravindakshan-Shweta-Mohan.mp3 -> song_f07dca0d5c49.mp3
# Copied: Oh-Maya-Harris-Jayaraj-Karunya-Ramya-NSK.mp3 -> song_f426c32df4f1.mp3
# Copied: Maatikichu-VM-Mahalingam.mp3 -> song_648a3ea13ed1.mp3
# Copied: Oru-Kuchi-Oru-Kulfi-TheSelfieSong-From-Kalakalappu-2-Hiphop-Tamizha-Gana-Vinoth-Saravedi-Saran.mp3 -> song_446e37d3a978.mp3
# Copied: Yaayum-Shabir-Sulthan-Naresh-Iyer-Rita-Thyagarajan.mp3 -> song_2f73f7c44889.mp3
# Copied: Senthoora-D-Imman-Luksimi-Sivaneswaralingam.mp3 -> song_4740952729fc.mp3
# Copied: Neethanae-From-Mersal-AR-Rahman-Shreya-Ghoshal.mp3 -> song_d15d65482bad.mp3
# Copied: Takkunu-Takkunu-From-Mr-Local-Hiphop-Tamizha-Anirudh-Ravichander.mp3 -> song_6562210a2c96.mp3
# Copied: Yaanji-From-Vikram-Vedha-Sam-CS-Anirudh-Ravichander-Shakthisree-Gopalan.mp3 -> song_08d629b4fcbf.mp3
# Copied: Yennai-Maatrum-Kadhale-Anirudh-RavichanderSid-Sriram.mp3 -> song_983ab50870c9.mp3
# Copied: Pogiren-Mugen-Rao-Prashan-Sean.mp3 -> song_5ee6e687da63.mp3
# Copied: Dhimu-Dhimu-Harris-Jayaraj-Karthik.mp3 -> song_a51bcb1fa5cd.mp3
# Copied: Mazhai-Varum-Female-Joshua-Sridhar-Suzanne-DMello.mp3 -> song_3a959e83813c.mp3
# Copied: Malai-Mangum-Neram-Ranina-Reddy.mp3 -> song_527c6fec825c.mp3
# Copied: Oh-Shanthi-Shanthi-Harris-Jayaraj-Clinton-SP-Charan.mp3 -> song_3c00ef160f8c.mp3
# Copied: Ennai-Saaithaalae-Harris-Jayaraj-Hariharan-Shreya-Ghoshal.mp3 -> song_419da1bec596.mp3
# Copied: Yaaro-Ivan-From-Udhayam-NH4-G-V-Prakash-Saindhavi.mp3 -> song_315b7c0851be.mp3
# Copied: Sol-Pechu-Yuvan-Shankar-Raja-K-S-Chithra-Shreya-Ghoshal.mp3 -> song_d9ada14709c5.mp3
# Copied: En-Kadhal-Solla-From-Paiya-Yuvan-Shankar-Raja-Tanvi-Shah.mp3 -> song_5c61f271dc96.mp3
# Copied: Enakenna-Yaarum-Illaye-From-Aakko-Anirudh-Ravichander.mp3 -> song_f8d9b912fd7d.mp3
# Copied: Po-Nee-Po-Remix-The-Scream-of-Love-Anirudh-Ravichander-Sathyaprakash-Harish-Swaminathan.mp3 -> song_ee38e253e01a.mp3
# Copied: Oh-Baby-Girl-Achu-Hemachandra-Vedala.mp3 -> song_3eac628e59ee.mp3
# Copied: Kadhal-Cricket-Love-Not-Out-Hiphop-Tamizha-Kharesma-Ravichandran.mp3 -> song_3b04acd03b57.mp3
# Copied: Azhage-Hiphop-Tamizha.mp3 -> song_8895646af3c4.mp3
# Copied: Ennavaley-Dhilip-Varman-Thila-Laxshman-Psychomantra-SaintTFC.mp3 -> song_2f627d98f0f5.mp3
# Copied: Po-Indru-Neeyaga-Anirudh-Ravichander-Dhanush.mp3 -> song_48e0ddb97d23.mp3
# Copied: Oxygen-Hiphop-TamizhaSudarshan-Ashok.mp3 -> song_06a728aed6d2.mp3
# Copied: Usuraiya-Tholaichaen-Stephen-Zechariah-Pragathi-Guruprasad.mp3 -> song_74c241a27017.mp3
# Copied: Kayalvizhi-Mugen-Rao.mp3 -> song_19442aca0a8a.mp3
# Copied: Kanne-Kanne-From-Ayogya-Anirudh-Ravichander.mp3 -> song_8f513f333361.mp3
# Copied: Onnume-Aagala-Anirudh-Ravichander-MALIII.mp3 -> song_a4bd15f9d996.mp3
# Copied: Rasaathi-Nenja-Madras-Gig-Season-2-Yuvan-Shankar-Raja-Dharan-Kumar.mp3 -> song_a286eafef5ca.mp3
# Copied: Vaa-Vaa-Penne-From-Uriyadi-2-Govind-Vasantha-Sid-Sriram-Priyanka-NK.mp3 -> song_1f636dfa23d5.mp3
# Copied: Lesa-Valichudha-From-Jasmine-C-Sathya-Sid-Sriram.mp3 -> song_e1de21446aa8.mp3
# Copied: Maya-Mugen-Rao.mp3 -> song_f2e2ce2d08b0.mp3
# Copied: Vaadi-Nee-Va-From-Meesaya-Murukku-Rajan-Chelliah-Hiphop-Tamizha.mp3 -> song_4cb8a41aa028.mp3
# Copied: Kadhalikathey-From-Imaikkaa-Nodigal-Hiphop-Tamizha-Kaushik-Krish.mp3 -> song_e1b0495d730d.mp3
# Copied: Breakup-Song-From-Naan-Sirithal-Hiphop-Tamizha.mp3 -> song_826b0fe053c3.mp3
# Copied: Usure-From-Sivappu-Manjal-Pachai-Siddhu-Kumar-Sudharshan-Ashok-Jothi-Pushpa.mp3 -> song_5aeb6362db43.mp3
# Copied: Konjam-1-Armaan-Malik.mp3 -> song_3b6081745b96.mp3
# Copied: Konjam-2-Armaan-Malik.mp3 -> song_0442cc0a6267.mp3
# Copied: Unnaal-Unnaal-Un-Ninaivaal-Palak-Muchhal.mp3 -> song_0b458e677968.mp3
# Copied: Saayaali-Sathyaprakash-Chinmayi.mp3 -> song_98a1be402e0f.mp3
# Copied: Yedhedho-Pennae-G-V-Prakash-Ajesh-Harini.mp3 -> song_ec72026ae673.mp3
# Copied: Kodi-Aruvi-Sean-Roldan-Pradeep-Kumar-Nithyashree-Venkataramanan.mp3 -> song_bc322025efec.mp3
# Copied: Marappadhilai-Nenje-Additional-Song-Leon-James-Sudharshan-Ashok.mp3 -> song_073b9e1d43b6.mp3
# Copied: Mailaanji-D-Imman-Pradeep-Kumar-Shreya-Ghoshal.mp3 -> song_180ea4e26fe3.mp3
# Copied: Idhu-Dhaan-From-Sivappu-Manjal-Pachai-Siddhu-Kumar-Naresh-Iyer-Shashaa-Tirupati.mp3 -> song_deffdc82e8b1.mp3
# Copied: Munbe-Vaa-Joshua-Aaron.mp3 -> song_c646fe9219f1.mp3
# Copied: Anji-Manikku-From-Puppy-Dharan-Kumar-Yuvan-Shankar-Raja-Shashaa-Tirupati.mp3 -> song_a6ccda515b3b.mp3
# Copied: Gaandu-Kannamma-Vivek-Mervin.mp3 -> song_bcd3370b1115.mp3
# Warning: Could not find file .webm.mp3 in All in one
# Copied: Vaseegara-And-Zara-Zara-Mashup-Jonita-Gandhi.mp3 -> song_1a8f4a7cf0fd.mp3
# Copied: Shades-of-Kadhal-Maran.mp3 -> song_be9e2092ace1.mp3
# Copied: Sathiyama-Mugen-Rao-Priyashankari.mp3 -> song_0c8195454dfe.mp3
# Copied: Sathiyama-Naan-Solluren-Di-Joshua-Aaron.mp3 -> song_28d9688e0dc0.mp3
# Copied: Yuvan-Mashup-2k18-Straight-from-Our-Hearts-Stanley-Xavier-Sathya-Narayanan.mp3 -> song_280a576cd305.mp3
# Copied: Yaar-Azhaippadhu-Ghibran-Sid-Sriram.mp3 -> song_599fe8543b97.mp3
# Copied: Rendu-Kaadhal-From-Kaathuvaakula-Rendu-Kaadhal-Anirudh-Ravichander-Shakthisree-Gopalan-Aishwarya-Sur.mp3 -> song_a9e2560892f7.mp3
# Copied: Snehidhane-Sadhana-Sargam-Srinivas.mp3 -> song_b5488e2657e9.mp3
# Copied: Naane-Varugiraen-AR-Rahman-Shashaa-Tirupati-Sathyaprakash.mp3 -> song_5e4fe0b7cafd.mp3
# Copied: High-On-Love-Yuvan-Shankar-RajaSid-Sriram.mp3 -> song_e5592ce2dbe2.mp3
# Copied: Oru-Kal-Oru-Kannadi-Rajramanan.mp3 -> song_3ee47f7670bf.mp3
# Copied: Nenjodu-Unnikrishnan-Sujatha.mp3 -> song_05ac4d7a6a65.mp3
# Copied: Yedho-Ondru-Harish-Raghavendra-Srilekha-Parthasarathy-Franko.mp3 -> song_1f5018d733ff.mp3
# Copied: Yennodu-Vaa-Vaa-Ilaiyaraaja-Karthik.mp3 -> song_aeb8d8a84130.mp3
# Copied: Parandhu-Sella-Vaa-AR-Rahman-Karthik-Shashaa-Tirupati.mp3 -> song_0fe3731c6959.mp3
# Copied: Un-Paarvaiyil-Karthik-Sumangaly.mp3 -> song_ff342f93b2cf.mp3
# Copied: Yaarumilla-AR-Rahman-Shweta-Mohan-Srinivas.mp3 -> song_adb5f0445717.mp3
# Copied: Laali-Laali-Ghibran-Sathyaprakash-Pragathi-Guruprasad-Raju-Murugan.mp3 -> song_edec860d9185.mp3
# Copied: Vaanam-Mella-Ilaiyaraaja-Bela-Shende.mp3 -> song_afb2179d039f.mp3
# Copied: Stanza-Cafe-Amal-Manohar-Geetesh-Iyer.mp3 -> song_f5a8a895dfd2.mp3
# Copied: Unnodu-Vazhatha-Bharadwaj-K-S-Chithra.mp3 -> song_892026ae3c7e.mp3
# Copied: Nenjam-Ellam-AR-Rahman-Adnan-Sami-Sujatha.mp3 -> song_e5a2f914b45c.mp3
# Copied: Nenjukkule-AR-Rahman-Shakthisree-Gopalan.mp3 -> song_90e8b4b805b1.mp3
# Copied: Oru-Naalil-Yuvan-Shankar-Raja.mp3 -> song_7f5bf99396f9.mp3
# Copied: Oru-Naalaikkul-Yuvan-Shankar-Raja-Karthik-Rita-Thyagarajan.mp3 -> song_7c34926456bc.mp3
# Copied: Konji-Pesida-Venaam-Nivas-K-Prasanna-K-S-Chithra-Sriram-Parthasarathy.mp3 -> song_26cb55a6883e.mp3
# Copied: Manmadhane-Nee-Yuvan-Shankar-Raja-Sadhana-Sargam.mp3 -> song_dcb64922bc93.mp3
# Copied: Oru-Manam-From-Dhruva-Natchathiram-Harris-Jayaraj-Karthik-Shashaa-Tirupati-Vikram.mp3 -> song_62e4597c3ede.mp3
# Copied: Mayilrage-Madhusree-Naresh-Iyer.mp3 -> song_3c9a67c5e52e.mp3
# Copied: Unnaale-Unnaale-Karthik-Krishh-Harini.mp3 -> song_334dbec346aa.mp3
# Copied: Neethane-Yuvan-Shankar-Raja.mp3 -> song_2cda26c2360c.mp3
# Copied: Siragugal-Yuvan-Shankar-Raja-Javed-Ali-Madhushree.mp3 -> song_47826a116477.mp3
# Copied: On-Nenappu-Sean-Roldan-Anirudh-Ravichander.mp3 -> song_78ffe79e7318.mp3
# Copied: Sakkarakatti-Hiphop-Tamizha.mp3 -> song_8c382e86fdb0.mp3
# Copied: Enna-Nadanthalum-Hiphop-Tamizha-Kaushik-Krish.mp3 -> song_777b44dccf1c.mp3
# Copied: Yaaraiyum-Ivlo-Azhaga-From-Sulthan-Vivek-Mervin-Silambarasan-TR.mp3 -> song_a03c82e3bed6.mp3
# Copied: For-You-Why-Dont-We.mp3 -> song_9c7467edd7c0.mp3
# Copied: Kadhal-Sadugudu-SP-Charan.mp3 -> song_5d8d28c4c563.mp3
# Copied: Kadhal-Yennulle-From-Neram-Rajesh-Murugesan-Ranjith-Govind.mp3 -> song_b82d0461c6a4.mp3
# Copied: Yedho-Ondru-Ennai-Yuvan-Shankar-Raja.mp3 -> song_f7b2c936066f.mp3
# Copied: Uyire-Uyire-Saagar-NaMuthukumar.mp3 -> song_299397715805.mp3
# Copied: Po-Po-Yen-Sid-Sriram-A-H-Kaashif.mp3 -> song_13fbdfe7c91a.mp3
# Copied: Mazhaiyin-Saaralil-Dharan-Kumar-Shweta-Mohan-Guna-Thamarai.mp3 -> song_0197a7ec7692.mp3
# Duplicate found: Po-Indru-Neeyaga-Anirudh-Ravichander-Dhanush.mp3 (already exists as song_48e0ddb97d23)
# Copied: So-Baby-From-Doctor-Anirudh-Ravichander-Ananthakrrishnan.mp3 -> song_0aeaf97f008e.mp3
# Copied: Oh-Shala-Oh-Shala-Yuvan-Shankar-Raja.mp3 -> song_e2d47906a388.mp3
# Copied: Enna-Solla-The-New-Life-of-Tamizh-Anirudh-Ravichander-Shweta-Mohan.mp3 -> song_92b02a667c46.mp3
# Copied: Visiri-Sid-Sriram-Shashaa-Tirupati.mp3 -> song_3f35cc55d20b.mp3
# Copied: Hey-Penne-From-Kattappava-Kanom-Santhosh-Dhayanidhi-Sid-Sriram-Alisha-Thomas-Aishwarya-Kumar.mp3 -> song_ceb30333f43f.mp3
# Copied: Kanna-Veesi-Siddhu-Kumar-rahul-Srinisha-Jayaseelan-Vignesh-Ramakrishna-Punith.mp3 -> song_f5c22ee0b9cf.mp3
# Copied: Kanna-Veesi-Reprise-Version-Siddhu-Kumar-rahul-Srinisha-Jayaseelan-Vignesh-Ramakrishna-Punith.mp3 -> song_ba71129b77be.mp3
# Copied: Oh-Sunandha-Raman-Mahadevan-Caroline-Megha.mp3 -> song_1b999b7a02be.mp3
# Copied: Kanaa-Nucleya-2jaym-Sublahshini.mp3 -> song_fa126ca55ced.mp3
# Copied: Mayilaanjiye-From-Sivappu-Manjal-Pachai-Siddhu-Kumar-Anand-Aravindakshan-Shashaa-Tirupati.mp3 -> song_e84ac2c59839.mp3
# Copied: Hosanna-AR-Rahman-Vijay-Prakash-Suzanne-DMello-Blaaze.mp3 -> song_7d260f8fefa7.mp3
# Copied: Kannukkul-Kannai-AR-Rahman-Naresh-Iyer.mp3 -> song_73db1d3a35cc.mp3
# Copied: Aaromale-AR-Rahman-Alphons-Joseph.mp3 -> song_717c9420eaa6.mp3
# Copied: Pesadhe-From-Thirudan-Police-Yuvan-Shankar-Raja-Harihara-Sudhan-Pooja.mp3 -> song_89a98eae45ad.mp3
# Copied: Kaatru-Veesum-Rajesh-Murugesan-Haricharan.mp3 -> song_572bc1ae2b33.mp3
# Copied: Scooter-Vandi-Ft-Kash-Villanz-and-Shamini-OG-Das.mp3 -> song_5b806dad352a.mp3
# Copied: Sandhipoma-AR-Rahman-Unni-Menon-Chandralekha-Annupamaa.mp3 -> song_ffa7c417cd29.mp3
# Copied: Enna-Naan-Seiven-Pradeep-Kumar-Kalyani-Nair.mp3 -> song_15b4aeda9d99.mp3
# Copied: Mazhaiye-Mazhaiye-Thaman-S-Ranjith-Govind.mp3 -> song_db432e39b610.mp3
# Copied: Yaaro-Ivan-G-V-Prakash-Saindhavi.mp3 -> song_063a4d4f8a9c.mp3
# Copied: Sundari-S-P-Balasubrahmanyam-S-Janaki.mp3 -> song_3bb27319ff59.mp3
# Copied: Pesugiraen-Neha-Bhasin.mp3 -> song_f2e1c02d31fc.mp3
# Copied: Hey-Umayaal-Achu-Vijay-Yesudas.mp3 -> song_a64852a48bd9.mp3
# Copied: Po-Po-Yen-Sid-Sriram-A-H-Kaashif.mp3 -> song_13fbdfe7c91a.mp3
# Copied: Verrattaama-Verratturiye-From-Veera-Leon-James-Sid-Sriram-Neeti-Mohan.mp3 -> song_75781af44151.mp3
# Copied: Pogatha-Yennavittu-Pradeep-Kumar-Sam-CS-Neha-Venugopal.mp3 -> song_6706b64838ff.mp3
# Copied: LONER-BGM-Nalini-Vittobane-ADY-KRIZ.mp3 -> song_049877aec363.mp3
# Copied: Cheap-Thrills-feat-Sean-Paul-Sia-Sean-Paul.mp3 -> song_0615263e2d61.mp3
# Copied: Neeyum-Naanum-Anbe-Hiphop-Tamizha-Raghu-Dixit-Sathyaprakash-D-Jithin-Raj.mp3 -> song_070d2939cb16.mp3
# Copied: Vilambara-Idaiveli-Hiphop-Tamizha-Srinisha-Jayaseelan-Sudarshan-Ashok-Christopher-Stanley.mp3 -> song_3f7a7b6d600f.mp3
# Copied: Undiporaadhey-Sid-Sriram.mp3 -> song_bf4ec2380eb9.mp3
# Copied: Seramal-Ponal-Vivek-Mervin-Mervin-Solomon-Sameera-Bharadwaj.mp3 -> song_d61e07779122.mp3
# Copied: Raati-Madras-Gig-Santhosh-Dhayanidhi-Bamba-Bakya.mp3 -> song_45894d548884.mp3
# Copied: Narumugaye-Aalaap-Raju-Madhu-Bala.mp3 -> song_80838f0b1bee.mp3
# Copied: Moongil-Kaadugalae-Hariharan-Tippu.mp3 -> song_0d439adf23a8.mp3
# Copied: Yaaro-En-Nenjai-Devi-Sri-Prasad-Sagar-Sumangaly.mp3 -> song_f46146738e4d.mp3
# Copied: Kannamma-From-Ispade-Rajavum-Idhaya-Raniyum-Sam-CS-Anirudh-Ravichander.mp3 -> song_81592f37cf0b.mp3
# Copied: Donu-Donu-Donu-From-Maari-The-Dons-Romance-Anirudh-Ravichander-Alisha-Thomas.mp3 -> song_f81236c03f19.mp3
# Copied: Mandhira-Kanniley-Chinmayi-Vijay-Deverakonda-Malobika-Mj.mp3 -> song_0f79e80043d4.mp3
# Copied: Levitating-feat-Prakriti-Kakar-Sukriti-Kakar-Amaal-Mallik-Remix-Dua-Lipa-Amaal-Mallik-Prakriti-Kakar.mp3 -> song_7c32dfa93130.mp3
# Copied: Oru-Devathai-Yuvan-Shankar-Raja-Roop-Kumar-Rathod.mp3 -> song_f1a829a72c66.mp3
# Copied: Neeyum-Naanum-Anirudh-Ravichander-and-Neeti-Mohan.mp3 -> song_8dee254c59c0.mp3
# Copied: Nira-From-Takkar-Sid-Sriram-Gautham-Vasudev-Menon-Malvi-Sundaresan-Nivas-K-Prasanna.mp3 -> song_6bc690a2b1b4.mp3
# Copied: Adi-Penne-Duet-From-Naam-Series-Stephen-Zechariah-T-Suriavelan-Srinisha-Jayaseelan.mp3 -> song_d4cfe0d4e257.mp3
# Copied: Kadhal-Oru-Aagayam-Hiphop-Tamizha-Teejay-Al-Rufian.mp3 -> song_69cd1858ada6.mp3
# Duplicate found: Neeyum-Naanum-Anbe-Hiphop-Tamizha-Raghu-Dixit-Sathyaprakash-D-Jithin-Raj.mp3 (already exists as song_070d2939cb16)
# Copied: Imaye-Imaye-G-V-Prakash-Shakthisree-Gopalan.mp3 -> song_2a313737c158.mp3
# Copied: Thodu-Vaanam-Harris-Jayaraj-Hariharan-Shakthisree-Gopalan.mp3 -> song_639f9f9ab37d.mp3
# Copied: Saayndhu-Saayndhu-Ilaiyaraaja-Yuvan-Shankar-Raja-Ramya-NSK.mp3 -> song_2ba3e9809030.mp3
# Copied: Thendral-Vandhu-Theendumbothu-From-Avathaaram-Ilaiyaraaja-S-Janaki.mp3 -> song_4e54e9d01534.mp3
# Copied: Orasaadha-Madras-Gig-Vivek-Mervin.mp3 -> song_638c79eaae35.mp3
# Copied: Kadhaippoma-From-Oh-My-Kadavule-Leon-James-Sid-Sriram.mp3 -> song_239babaa5d6a.mp3
# Copied: Yaen-Ennai-Pirindhaai-Sid-Sriram.mp3 -> song_5ba998f116cb.mp3
# Duplicate found: Sandhipoma-AR-Rahman-Unni-Menon-Chandralekha-Annupamaa.mp3 (already exists as song_ffa7c417cd29)
# Copied: Paarthen-The-Youth-Of-Power-Paandi-Sean-RoldanShweta-Mohan.mp3 -> song_ba19f7dba410.mp3
# Copied: Kannadi-Poovukku-Santhosh-DhayanidhiHaricharanJonita-Gandhi.mp3 -> song_adb8520e19e6.mp3
# Copied: Inna-Mylu-From-Lift-Britto-Michael-Sivakarthikeyan-Poovaiyar-Kamala-Kannan-Rajesh.mp3 -> song_0e81c18874d9.mp3
# Copied: Nethu-From-Jagame-Thandhiram-Santhosh-Narayanan-Dhanush.mp3 -> song_e5dabcbcc40b.mp3
# Copied: Pagal-Iravai-Maraigirai-Pranav-Das.mp3 -> song_a914c97458e0.mp3
# Copied: Nallai-Allai-AR-Rahman-Chinmayi-Sathyaprakash.mp3 -> song_fd749732f428.mp3
# Copied: Malare-Vidyasagar-S-P-Balasubrahmanyam-S-Janaki.mp3 -> song_58cd27cac120.mp3
# Copied: En-Kadhale-S-P-Balasubrahmanyam-Noel-James.mp3 -> song_31e1eda1d86d.mp3
# Copied: Minnalea-En-Vazhvin-S-P-Balasubrahmanyam.mp3 -> song_4256c34a88d6.mp3
# Copied: Solladi-Tippu-Chorus.mp3 -> song_a5fd9ec601c4.mp3
# Copied: Venmathiye-Tippu.mp3 -> song_b8d002ba9d4a.mp3
# Copied: Verenna-Ivan-Yaro-Unnikrishnan-Harini.mp3 -> song_db1643c0987f.mp3
# Copied: Nenjai-Poopol-Harish-Raghavendra.mp3 -> song_c7c3948428e5.mp3
# Copied: Minnalai-Pidithu-Unni-Menon.mp3 -> song_adbd54e46c0a.mp3
# Copied: Aye-Mr-Minor-AR-Rahman-Haricharan-Shashaa-Tirupati.mp3 -> song_77623445f5b6.mp3
# Copied: Paartha-Mudhal-Unni-Menon-Bombay-Jayashri.mp3 -> song_5bb1c831da54.mp3
# Copied: Puriyavillai-Shweta-Mohan.mp3 -> song_c463914c5ccd.mp3
# Copied: Paisa-Note-Hiphop-Tamizha.mp3 -> song_6e3a9b7456f4.mp3
# Copied: Kadhal-Kan-Kattudhe-Anirudh-RavichanderShakthishree-Gopalan.mp3 -> song_9d9c5303b3b1.mp3
# Copied: Kaadhal-kaditham-From-Jodi-Unni-Menon-S-Janaki.mp3 -> song_e62b4ec31df0.mp3
# Copied: Un-Per-Solla-Duet-Version-Sujatha-Mohan-Hariharan.mp3 -> song_79564cd62dcb.mp3
# Copied: Naan-Dhaan-Da-Mass-Santhosh-Narayanan-ofRO-Arivu.mp3 -> song_0a5346a64788.mp3
# Copied: Sevatha-Pulla-Ghibran-Ranjith-Govind.mp3 -> song_a1583f3d7dfc.mp3
# Copied: Kaathadi-Anand-Kashinath-Sublahshini.mp3 -> song_325c20ae3f74.mp3
# Copied: En-Moochum-Venam-Ranjith-Govind.mp3 -> song_e203c4a06cb0.mp3
# Copied: Thozhiya-Harish-Raghavendra-Sri-Charan-Mega-Chorus.mp3 -> song_cc55f2c8321b.mp3
# Copied: Thooriga-From-Navarasa-Karthik.mp3 -> song_1dec435a07fe.mp3
# Copied: Manjal-Veyil-Hariharan-Nakul-Vijay.mp3 -> song_0058b87a6465.mp3
# Copied: Vaadi-Vaadi-Vijay.mp3 -> song_317219b8c469.mp3
# Duplicate found: Anbil-Avan-AR-Rahman-Chinmayi-Devan-Ekambaram.mp3 (already exists as song_1f536bba5b5a)
# Copied: Muzumathi-AR-Rahman-Srinivas.mp3 -> song_de9d95d6090e.mp3
# Copied: Kan-Irandil-Vijay-Antony-Naresh-Iyer.mp3 -> song_1600b91b6340.mp3
# Copied: En-Nenju-Vijay-Prakash-Vijay-Antony-Saindhavi.mp3 -> song_b6412a82aa94.mp3
# Copied: Raja-Raja-Chozhan-Reprise-Version-Tajmeel-Sherif.mp3 -> song_367b0ae19051.mp3
# Copied: Un-Per-Solla-Aasaidhan-Reprise-Tajmeel-Sherif.mp3 -> song_d37db9f3e63a.mp3
# Copied: Nenjinile-Male-Version-Tajmeel-Sherif-Pavan-Kumar.mp3 -> song_5befb502a1c7.mp3
# Copied: Sundari-Kannal-Oru-Reprise-Tajmeel-Sherif.mp3 -> song_325fc82b6436.mp3
# Copied: Nenjinile-Rebirth-Chris-G-Mc-Sai-Sahi-Siva.mp3 -> song_dad87be7aa76.mp3
# Copied: Ennoda-Laila-Vijay-Palani-Bharathi.mp3 -> song_c7204620142d.mp3
# Copied: Kaadhal-Solvadhu-Srinivas-Sunitha-Palani-Bharathi.mp3 -> song_1ea17d193319.mp3
# Copied: Vaseegara-Bombay-Jayashri.mp3 -> song_2e12350ab9a7.mp3
# Copied: Valayosai-Reprise-Tajmeel-Sherif.mp3 -> song_9c28090f7d2d.mp3
# Copied: Melliname-Melliname-Tajmeel-Sherif.mp3 -> song_3765e59b7fdb.mp3
# Copied: New-York-Nagaram-Reprise-Tajmeel-Sherif.mp3 -> song_e4d5eb3d4499.mp3
# Copied: Kammani-Kamal-Haasan-S-Janaki.mp3 -> song_9e00cc61148c.mp3
# Copied: Yaar-Indha-Saalai-Oram-G-V-Prakash-Saindhavi.mp3 -> song_959190746f34.mp3
# Copied: Thean-Kudika-Teejay-Pragathi.mp3 -> song_74a5828ce918.mp3
# Copied: Azhagiya-Asura-Anitha-Chandrasekar.mp3 -> song_4d49e8be6c11.mp3
# Copied: Unnaal-Penne-From-Dharala-Prabhu-Inno-Genga.mp3 -> song_022de325c3ff.mp3
# Copied: Gore-Gore-Thaman-S-Karthik-Suchitra.mp3 -> song_05113e936317.mp3
# Copied: THENDRAL-VANTHU-Unplugged-Sabari-Darshan-Deepak-Chander.mp3 -> song_885a7c4e33e7.mp3
# Duplicate found: Orasaadha-Madras-Gig-Vivek-Mervin.mp3 (already exists as song_638c79eaae35)
# Copied: Omana-Penne-AR-Rahman-Benny-Dayal-Kalyani-Menon.mp3 -> song_47b8323eabdb.mp3
# Duplicate found: Kannukkul-Kannai-AR-Rahman-Naresh-Iyer.mp3 (already exists as song_73db1d3a35cc)
# Copied: Vinnaithaandi-Varuvaayaa-AR-Rahman-Karthik-Vivek-Agrawal.mp3 -> song_54af5dad1c89.mp3
# Copied: Vinmeen-Nivas-K-Prasanna-Abhay-Jodhpurkar-Saindhavi.mp3 -> song_82ee859306c7.mp3
# Copied: En-Anbay-Shankar-Mahadevan.mp3 -> song_1a97bf58c0f0.mp3
# Copied: Sudasuda-Thooral-Yuvan-Shankar-Raja.mp3 -> song_20f7a3fd07dc.mp3
# Copied: Enthaaraa-Enthaaraa-Ghibran-Shadab-Faridi-Chinmayi.mp3 -> song_ecbca5853ac6.mp3
# Copied: Chellakuttiye-Jecin-George-Pearle-Maaney-Srinish-Aravind.mp3 -> song_b34259502c50.mp3
# Copied: Naanum-From-Navarasa-Karthik.mp3 -> song_6f67ca163850.mp3
# Copied: Eppa-Paarthaalum-From-Aalambana-Hiphop-Tamizha-Armaan-Malik.mp3 -> song_4b67bdd2bce9.mp3
# Copied: Idhuvum-Kadandhu-Pogum-The-Healing-Song-From-Netrikann-Girishh-G-Sid-Sriram.mp3 -> song_41eeb6fb36b8.mp3
# Duplicate found: Nenjinile-Rebirth-Chris-G-Mc-Sai-Sahi-Siva.mp3 (already exists as song_dad87be7aa76)
# Copied: Yaaro-Duet-Version-S-P-Balasubrahmanyam-K-S-Chithra.mp3 -> song_3dd3897014af.mp3
# Copied: Raataan-Lambiyan-From-Shershaah-Tanishk-Bagchi-Jubin-Nautiyal-Asees-Kaur.mp3 -> song_3107d85872e6.mp3
# Copied: Osaka-Osaka-Anirudh-Ravichander-Pragathi-Guruprasad-Madhan-Karky.mp3 -> song_21260761b1e7.mp3
# Copied: My-Universe-Acoustic-Version-Coldplay-BTS.mp3 -> song_910f048c7fc2.mp3
# Copied: Kannamma-Eannamma-Sam-Vishal.mp3 -> song_ee9afaa0bc99.mp3
# Copied: Soul-of-Doctor-Theme-From-Doctor-Anirudh-Ravichander-Niranjana-Ramanan.mp3 -> song_b004e71ac037.mp3
# Duplicate found: Venmathiye-Tippu.mp3 (already exists as song_b8d002ba9d4a)
# Copied: Aasai-Oru-Pulveli-Santhosh-Narayanan-Pradeep-Kumar-Kalyani-Nair.mp3 -> song_7e3f18327788.mp3
# Copied: Velicha-Poove-Anirudh-Ravichander-Mohit-Chauhan-Shreya-Ghoshal.mp3 -> song_dbbb8e7b487e.mp3
# Copied: Naan-Pizhaippeno-Sathyaprakash.mp3 -> song_8ccd53216eb6.mp3
# Copied: Kadhal-Pisase-Udit-Narayan-Sujatha.mp3 -> song_2d94ee89f637.mp3
# Copied: Yaaro-Manadhile-Swetha-Manas.mp3 -> song_8261e3a9fd8b.mp3
# Copied: Saara-Kaattrae-From-Annaatthe-D-Imman-Shreya-Ghoshal-Sid-Sriram.mp3 -> song_c0c0768eb3e7.mp3
# Copied: Poongatre-Poongatre-Yuvan-Shankar-Raja-Benny-Dayal.mp3 -> song_8d377670feb1.mp3
# Copied: Raataan-Lambiyan-Tanishk-Bagchi-Jubin-Nautiyal-Asees-Kaur.mp3 -> song_3a8e7bb65581.mp3
# Copied: Adiyae-Kolluthey-Harris-Jayaraj-Krishh-Benny-Dayal-Shruti-Haasan.mp3 -> song_3904517e6407.mp3
# Copied: Yaaradiyo-From-Gorilla-Sam-CS-Sid-Sriram.mp3 -> song_c5a5421dbb5d.mp3
# Copied: Oru-Murai-Blaaze-Andrea-Jeremiah.mp3 -> song_6b3d8bd06d76.mp3
# Copied: Abinaya-Mugen-Rao.mp3 -> song_ffcd83a4c85f.mp3
# Copied: Adiye-From-Bachelor-Dhibu-Ninan-Thomas-Kapil-Kapilan.mp3 -> song_3d7e6fc8b184.mp3
# Copied: Kadhal-Yennulle-Rajesh-Murugesan-Ranjith-Govind.mp3 -> song_7449b00aeeaf.mp3
# Copied: Thendral-Vanthu-Ilaiyaraaja-S-Janaki.mp3 -> song_23b8b0fa40ce.mp3
# Copied: Karu-Karu-Karthik-Naresh-Iyer-Krishh.mp3 -> song_5e036c78dba8.mp3
# Copied: Po-Urave-Sid-Sriram.mp3 -> song_6f1121951f87.mp3
# Copied: Haiyo-Haiyo-From-Oh-My-Kadavule-Leon-James.mp3 -> song_1c75f735ffcb.mp3
# Copied: Ailesa-Shakti-Sivamani.mp3 -> song_5a5c00e9a0d8.mp3
# Copied: Vizhigalil-Vizhigalil-Harish-Raghavendra.mp3 -> song_2e212edeff56.mp3
# Copied: Scarborough-Yanchan-Produced.mp3 -> song_11c5618df96a.mp3
# Copied: Neela-Vaanam-Priya-Hemesh-Kamal-Haasan.mp3 -> song_ec98c687a690.mp3
# Copied: Vaayamoodi-Summa-Iru-Da-Unplugged-Aakash-Srinivasan.mp3 -> song_a37adfd57705.mp3
# Copied: Kannamma-Sam-CS-Anirudh-Ravichander.mp3 -> song_0379b1a56446.mp3
# Duplicate found: Po-Urave-Sid-Sriram.mp3 (already exists as song_6f1121951f87)
# Copied: Jalabulajangu-From-Don-Anirudh-Ravichander-Rokesh.mp3 -> song_54ba3661c057.mp3
# Copied: Naan-Pizhai-From-Kaathuvaakula-Rendu-Kaadhal-Anirudh-Ravichander-Ravi-G-Shashaa-Tirupati.mp3 -> song_16ed4eb13058.mp3
# Copied: Indru-Netru-Naalai-Hiphop-Tamizha-Shankar-Mahadevan-Aalaap-Raju.mp3 -> song_cdc1fd4e7bb5.mp3
# Duplicate found: Yaar-Indha-Saalai-Oram-G-V-Prakash-Saindhavi.mp3 (already exists as song_959190746f34)
# Copied: Para-Para-NR-Raghunanthan-G-V-Prakash.mp3 -> song_991885d0b5ae.mp3
# Copied: Unnai-Kandane-Haricharan-Sruthi.mp3 -> song_c04fbf34e9e1.mp3
# Copied: Kandaangi-Kandaangi-Vijay-Shreya-Ghoshal.mp3 -> song_1b102e8b98e9.mp3
# Copied: Mun-Paniya-S-P-Balasubrahmanyam-Malgudi-Subha-Palani-Bharathi.mp3 -> song_3d3c8690b59f.mp3
# Copied: Unnai-Naan-Hariharan.mp3 -> song_eb3a71a38c0a.mp3
# Copied: Ondra-Renda-Bombay-Jayashri-Thamarai.mp3 -> song_fe697801ac3d.mp3
# Copied: Ennai-Konjum-Timmy-Tippu-Pop-Shalini-Thamarai.mp3 -> song_14d1d3410348.mp3
# Copied: Uyirin-Uyire-Krishnakumar-Kunnath-Suchitra-Thamarai.mp3 -> song_9d97e8ee99cf.mp3
# Duplicate found: Kannamma-Eannamma-Sam-Vishal.mp3 (already exists as song_ee9afaa0bc99)
# Copied: Kathari-Poovazhagi-Adhya.mp3 -> song_b1cbb2fa67aa.mp3
# Copied: Sathiyama-Sollurandi-From-Velan-Shane-Extreme-Gopi-Sundar-Mugen-Rao-Sivaangi-Krishnakumar.mp3 -> song_6da80a429bba.mp3
# Copied: Kaathodu-Kaathanen-From-Jail-G-V-Prakash-Dhanush-Aditi-Rao-Hydari.mp3 -> song_6061714295af.mp3
# Copied: Nethu-Rendition-Ajay-Jameson.mp3 -> song_f91eca96ba50.mp3
# Copied: Saara-Kaattrae-Shreya-Ghoshal-Sid-Sriram.mp3 -> song_b006a7d73d18.mp3
# Copied: Srivalli-From-Pushpa-The-RiseTamil-Devi-Sri-Prasad-Sid-Sriram-Viveka.mp3 -> song_4da3d37802b6.mp3
# Copied: Sandakari-Neethan-From-Sangathamizhan-Vivek-Mervin-Anirudh-Ravichander-Jonita-Gandhi-Mervin-Solomon.mp3 -> song_4925f27f8c31.mp3
# Copied: Kaariga-Sundaramurthy-KS-Sid-Sriram-Madhan-Karky.mp3 -> song_dab1366412f3.mp3
# Copied: Stylish-Thamizhachi-Yuvan-Shankar-Raja-MMManasi-Rubba-BendPsycho-Unit.mp3 -> song_7f4b49607ff5.mp3
# Copied: Nijamellam-Maranthupochu-From-Ethir-Neechal-Anirudh-Ravichander-Dhanush.mp3 -> song_4ce10eaafdab.mp3
# Copied: Anbe-Anbe-From-Darling-G-V-Prakash.mp3 -> song_20254d5657d7.mp3
# Copied: Kanaa-Kaangiren-G-V-Prakash-Shubha-Mudgal-Nithyasree-Mahadevan-Vinitra.mp3 -> song_6be4ae6bfe8f.mp3
# Copied: Aathadi-Aathadi-Harris-Jayaraj-Bhavatharini-Tippu-Dhanush-Abhay-Jodhpurkar.mp3 -> song_6da57a9d0db8.mp3
# Copied: Molachu-Moonu-Vijay-Antony-VV-Prassanna-Supriya-Joshi.mp3 -> song_37f5cda6938a.mp3
# Copied: Chinna-Thamarai-Vijay-Antony-Krishh-Suchitra.mp3 -> song_a7031cdbdc17.mp3
# Copied: Mayam-Seidhayo-Vijay-Antony-Sangeetha-Rajeshwaran.mp3 -> song_d4c03bc0af47.mp3
# Copied: Mayilirage-Unplugged-MD-Musiq.mp3 -> song_cad0875f41c0.mp3
# Copied: Sathiyama-Naan-Solluren-Di-X-Pogiren-Unplugged-MD-Musiq.mp3 -> song_07f2e7530671.mp3
# Copied: Snehithane-Male-Version-Tajmeel-Sherif-Pavan-Kumar.mp3 -> song_65956fb4658d.mp3
# Copied: Iragai-Poley-Yuvan-Shankar-Raja-Tanvi-Shah.mp3 -> song_ea2808f3558a.mp3
# Copied: Kaadhal-Vaithu-Vijay-Yesudas.mp3 -> song_bb8093ca5df8.mp3
# Warning: Could not find file .webm.mp3 in All in one
# Copied: Nan-pogiren-James-Vasanthan-S-P-Balasubrahmanyam-K-S-Chithra.mp3 -> song_5a4d3a0d5f55.mp3
# Copied: Thuli-Thuli-From-Paiya-Yuvan-Shankar-Raja-Haricharan-Tanvi-Shah.mp3 -> song_2468d06448ed.mp3
# Copied: Pachai-Nirame-Hariharan-Clinton-Cerejo.mp3 -> song_5f0ad7253bdf.mp3
# Copied: Usuru-Narambulay-Dhee.mp3 -> song_03b0c0614f1f.mp3
# Copied: Pennalla-Pennalla-Reprise-Tajmeel-Sherif.mp3 -> song_d7961c1aa46d.mp3
# Copied: Pennalla-Pennalla-Karthik-S.mp3 -> song_5c4f0c57b72f.mp3
# Copied: Priyathama-Priyathama-Chinmayi.mp3 -> song_7adeaf94bb50.mp3
# Copied: Vaaya-Veera-Shakthisree-Gopalan-Leon-James.mp3 -> song_bafb1bd5019a.mp3
# Copied: Pookkalae-Sattru-Oyivedungal-AR-Rahman-Haricharan-Madhan-Karky-Shreya-Ghoshal.mp3 -> song_91fc4258d318.mp3
# Copied: Mudhal-Nee-Mudivum-Nee-Title-Track-From-Mudhal-Nee-Mudivum-Nee-Darbuka-Siva-Sid-Sriram.mp3 -> song_6ee06b0c6605.mp3
# Copied: Vaa-Vennila-Unnaithane-From-Mella-Thirandhadhu-Kadhavu-S-P-Balasubrahmanyam-P-Susheela.mp3 -> song_bbc367f546ca.mp3
# Copied: Mun-Paniya-From-Nandhaa-S-P-Balasubrahmanyam-Malgudi-Subha.mp3 -> song_bba332cbc79d.mp3
# Copied: Ennai-Kollathey-Kumaresh-Keshini.mp3 -> song_72fbdff8214d.mp3
# Copied: Oru-Poiyavathu-From-Jodi-Srinivas-Sujatha.mp3 -> song_cc553c20855c.mp3
# Copied: Nenjinile-From-Uyire-S-Janaki.mp3 -> song_e1ff870e8079.mp3
# Copied: Enna-Solla-Pogirai-Shankar-Mahadevan.mp3 -> song_04decdd945ea.mp3
# Copied: Yemma-Yea-Alagamma-Bombay-Jayashri-Haricharan-Madhan-Karky.mp3 -> song_7c5ad392d738.mp3
# Copied: Medhakavitta-Medhakavitta-Yazin-Nizar-Sanjana-Kalmanji.mp3 -> song_e09ecf8cb142.mp3
# Copied: Selfie-Pulla-From-Kaththi-Vijay-Sunidhi-Chauhan.mp3 -> song_549096563b6f.mp3
# Copied: Vaan-AR-Rahman-Shashaa-Tirupati.mp3 -> song_dd653e3e0807.mp3
# Copied: Nenjam-Ennum-Devi-Sri-Prasad-Kalpana-Patowary.mp3 -> song_4b8517026f14.mp3
# Copied: Bae-From-Don-Anirudh-Ravichander-Adithya-RK.mp3 -> song_db84b1797dcf.mp3
# Copied: Uyir-Uruvaatha-Sam-CS-Sathyaprakash-Chinmayi.mp3 -> song_f8611e114eb6.mp3
# Copied: Travel-with-Me-Danny-Rayel.mp3 -> song_bebb00143a1e.mp3
# Copied: Nee-Yenadharuginil-Nee-Vishal-Chandrashekhar-Shakthisree-Gopalan.mp3 -> song_f241fdf33772.mp3
# Copied: Arabic-Kuthu-Halamithi-Habibo-From-Beast-Anirudh-Ravichander-Jonita-Gandhi.mp3 -> song_8933d28c63e9.mp3
# Copied: Un-Paarvai-Vijay-Yesudas.mp3 -> song_177c1c6fca00.mp3
# Copied: Mun-Paniya-From-Nandhaa-S-P-Balasubrahmanyam-Malgudi-Subha.mp3 -> song_bba332cbc79d.mp3
# Copied: Mayakirriye-Anivee-Anirudh-Ravichander.mp3 -> song_b90a56529849.mp3
# Copied: Kannai-Vittu-From-Iru-Mugan-Harris-Jayaraj-Tippu-Pravin-Saivi-Srimathumitha-Madhan-Karky.mp3 -> song_a1a65589ea9f.mp3
# Copied: Kannaane-Kanne-Sean-Roldan.mp3 -> song_8ed2c2e78a61.mp3
# Copied: Po-Nee-Po-Lofi-Flip-Anirudh-Ravichander-Nakul-Abhyankar-Mohit-Chauhan.mp3 -> song_99ca2a2f926c.mp3
# Copied: Maaris-Aanandhi-Ilaiyaraaja-MMManasi.mp3 -> song_000898caab64.mp3
# Copied: Donu-Donu-Donu-The-Dons-Romance-Anirudh-Ravichander-Alisha-Thomas.mp3 -> song_df952085520f.mp3
# Copied: Innum-Konjam-Naeram-AR-Rahman-Vijay-Prakash-Shweta-Mohan.mp3 -> song_893141da3260.mp3
# Copied: Pudhu-Vellai-Mazhai-From-Roja-Unni-Menon-Sujatha.mp3 -> song_c84b3f6e63c0.mp3
# Copied: Naan-Aval-Illai-From-Masss-Karthik-Chinmayi.mp3 -> song_19ab14fa9963.mp3
# Copied: Mother-Song-From-Valimai-Yuvan-Shankar-Raja-Sid-Sriram-Vignesh-Shivan.mp3 -> song_3bf50c32d3d9.mp3
# Copied: Enadhuyire-From-Bheema-Nikkil-Mathew-Chinmayi-Sadhana-Sargam.mp3 -> song_7c4455a0cfb6.mp3
# Copied: Pudhu-Vellai-Mazhai-Unni-Menon-Sujatha.mp3 -> song_d952b4299487.mp3
# Copied: Malang-Title-Track-From-Malang-Unleash-The-Madness-Ved-Sharma-Kunaal-Vermaa.mp3 -> song_037e3f310703.mp3
# Copied: Ajukku-Gumukku-Hiphop-Tamizha.mp3 -> song_63cdd9df34a2.mp3
# Copied: Paisa-Note-From-Comali-Hiphop-Tamizha.mp3 -> song_dbb513328ec5.mp3
# Copied: Ottraikkannale-Yuvan-Shankar-Raja-Haricharan-Suchitra.mp3 -> song_b7ac448ef946.mp3
# Copied: Aasai-Aasai-Shankar-Mahadevan-Sujatha-Kabilan.mp3 -> song_1627440308de.mp3
# Copied: Chudithar-Aninthu-Hariharan-Sadhana-Sargam.mp3 -> song_6bdbc26724ab.mp3
# Copied: Enna-Solla-Pogirai-Shankar-Mahadevan.mp3 -> song_04decdd945ea.mp3
# Copied: Enna-Saththam-Indha-Neram-S-P-Balasubrahmanyam.mp3 -> song_5ba8b46875ae.mp3
# Copied: Kadhalikathey-Hiphop-Tamizha-Kaushik-Krish.mp3 -> song_a9f0c5efde54.mp3
# Copied: Yathe-Yathe-G-V-Prakash.mp3 -> song_87e4a00d6cbe.mp3
# Copied: Ayyo-Ayyo-Srikanth-Deva-Udit-Narayan-Pop-Shalini.mp3 -> song_fd758c0bf997.mp3
# Copied: Kadhale-Kadhale-Hiphop-Tamizha-Shankar-Mahadevan-Padmalatha.mp3 -> song_05c0f5e50fa2.mp3
# Copied: Nenjukulla-Nee-Vijay-PrakashDiwakarAjesh.mp3 -> song_a201aaeccf95.mp3
# Copied: Un-Vizhigalil-From-Darling-Harini.mp3 -> song_a93b8eac998d.mp3
# Duplicate found: Yathe-Yathe-G-V-Prakash.mp3 (already exists as song_87e4a00d6cbe)
# Copied: Naan-Un-Arijit-Singh-Chinmayi.mp3 -> song_07089b036f78.mp3
# Duplicate found: Nan-pogiren-James-Vasanthan-S-P-Balasubrahmanyam-K-S-Chithra.mp3 (already exists as song_5a4d3a0d5f55)
# Copied: Oh-Senyoreeta-Unnikrishnan.mp3 -> song_e857f6f81e53.mp3
# Copied: Vaarayo-Vaarayo-Harris-Jayaraj-Chinmayi-Unnikrishnan-Mega.mp3 -> song_5f0b8b294e0a.mp3
# Copied: Be-Free-Vidya-Vox.mp3 -> song_d66747d30120.mp3
# Copied: Kamala-From-Sangathamizhan-Vivek-Mervin-Vivek-Siva-Sanjana-Kalmanje.mp3 -> song_adac8aace73c.mp3
# Copied: Anbe-En-Anbe-Harris-Jayaraj-Harish-Raghavendra.mp3 -> song_3e3eff8f2ba2.mp3
# Copied: Oh-Sunanda-G-V-Prakash-Raman-Mahadevan-Caroline-Megha-Nivas-Rahul-Nambiar-Chinmayi-Jurrian-Danielle.mp3 -> song_1f8581fdbfda.mp3
# Copied: Darshana-From-Hridayam-Hesham-Abdul-Wahab-Darshana-Rajendran-Arun-Alat.mp3 -> song_2200d78f3948.mp3
# Copied: Elangaathu-Veesudhey-Anju-Brahmasmi.mp3 -> song_f2699a4f5392.mp3
# Copied: Kuru-Kuru-Sundar-Narayana-Rao.mp3 -> song_78d088b0e467.mp3
# Copied: Maya-Nadhi-Santhosh-Narayanan-Ananthu-Pradeep-Kumar-Shweta-Mohan.mp3 -> song_4931ae62cad3.mp3
# Warning: Could not find file .webm.mp3 in All in one
# Copied: Thathaka-Theithare-Hesham-Abdul-Wahab-Prithviraj-Sukumaran.mp3 -> song_d08da9f9632c.mp3
# Copied: Imaikkariye-From-Selfie-G-V-Prakash-Manasvini-Gopal.mp3 -> song_2de0a4fbaace.mp3
# Copied: Let-Me-Down-Slowly-Alec-Benjamin.mp3 -> song_30027493a425.mp3
# Copied: Unnai-Ninaikave-Reshmi.mp3 -> song_ba12837d3245.mp3
# Copied: Eppo-Nee-G-V-Prakash-Madhusree.mp3 -> song_7305e1a1ac76.mp3
# Copied: Pudichiruka-Illa-Pudikalaya-Hiphop-Tamizha-Kaushik-Krish-Padmalatha-Velmurugan.mp3 -> song_26eeb89cb73e.mp3
# Copied: Kona-Kondakari-NR-Raghunanthan-G-V-Prakash.mp3 -> song_91cea5ef9aca.mp3
# Copied: Yaeley-Yaeley-Maruthu-D-Imman-Sooraj-Santhosh.mp3 -> song_aa8ffd441257.mp3
# Copied: Ei-Suzhali-Santhosh-Narayanan-Vijaynarain.mp3 -> song_bc517027f25d.mp3
# Copied: Mazhai-Vara-Pogudhae-From-Yennai-Arindhaal-Harris-Jayaraj-Karthik-Emcee-Jesz.mp3 -> song_10f5d0f8cb0e.mp3
# Copied: Beast-Mode-From-Beast-Anirudh-Ravichander.mp3 -> song_086078e792f2.mp3
# Copied: Kaarkuzhal-Kanmani-Sebastin-Rozario-Sam-Vishal.mp3 -> song_5d6f7b59ad0d.mp3
# Copied: Hold-Me-Now-Sanjith-Hegde-Yuvan-Shankar-Raja-Thurga.mp3 -> song_4d72f85e595a.mp3
# Copied: Kani-Mozhiyae-Harris-Jayaraj-Karthik.mp3 -> song_a32eebc098b8.mp3
# Copied: En-Fuse-Pochu-From-Arrambam-Yuvan-Shankar-Raja-Karthik-Ramya-NSK.mp3 -> song_b11caa6ecd18.mp3
# Copied: Sonapareeya-AR-Rahman-Javed-Ali-Haricharan-Nakash-Aziz.mp3 -> song_d74cc0f3c596.mp3
# Copied: Oh-Maname-Harris-Jayaraj-Hariharan.mp3 -> song_53b89c4f84a1.mp3
# Copied: Heat-Waves-Glass-Animals.mp3 -> song_550477cd094c.mp3
# Copied: Thendral-Vandhu-Theendumbothu-From-Avathaaram-Ilaiyaraaja-S-Janaki.mp3 -> song_4e54e9d01534.mp3
# Copied: Raja-Raja-Chozhan-K-J-Yesudas.mp3 -> song_10f77d7749b2.mp3
# Copied: Oru-Maalai-Karthik.mp3 -> song_9d29a01d3a17.mp3
# Copied: Dippam-Dappam-From-Kaathuvaakula-Rendu-Kaadhal-Anirudh-Ravichander-Anthony-Daasan.mp3 -> song_4081dd1651e3.mp3
# Copied: Come-on-Girls-The-Celebration-of-Love-Anirudh-Ravichander-Nadisha-Thomas-MALIII.mp3 -> song_ea28ae2e1bee.mp3
# Copied: Ragasiyamanadhu-Kadhal-Sirpy-Harish-Raghavendra-Harini.mp3 -> song_5e65df2c7965.mp3
# Copied: Chellakuttiye-Avastha-Love-Song-Jecin-George-Pearle-Maaney-Srinish-Aravind.mp3 -> song_541d07afb3ee.mp3
# Copied: Enadhuyire-From-Bheema-Nikkil-Mathew-Chinmayi-Sadhana-Sargam.mp3 -> song_7c4455a0cfb6.mp3
# Copied: Malai-Mangum-Neram-Ranina-Reddy.mp3 -> song_527c6fec825c.mp3
# Copied: Thozhi-From-Hey-Sinamika-Govind-Vasantha-Pradeep-Kumar.mp3 -> song_95e16755434b.mp3
# Copied: Ale-Ale-AR-Rahman-Karthik-Chitra-Sivaraman.mp3 -> song_3e8f5b14ea1d.mp3
# Copied: Vidigindra-Pozhudhu-Madhumitha.mp3 -> song_5b6bdeb6d2b4.mp3
# Copied: Nee-Cadbury-Barath-Dhanasekar-Aishwerya-Radhakrishnan.mp3 -> song_4d7c125b4716.mp3
# Copied: Dailamo-Dailamo-Vijay-Antony-Sangeetha-Rajeshwaran.mp3 -> song_895fc1a49e45.mp3
# Copied: Naetru-Aval-Irundhal-AR-Rahman-Chinmayi-Vijay-Prakash.mp3 -> song_9ed749f8fad3.mp3
# Copied: Left-and-Right-Feat-Jung-Kook-of-BTS-Charlie-Puth-Jung-Kook-BTS.mp3 -> song_cddf5a18b783.mp3
# Copied: Porkanda-Singam-EDM-Version-From-Vikram-Anirudh-Ravichander.mp3 -> song_1f82baabe88e.mp3
# Copied: Naani-Koni-Harris-Jayaraj-Vijay-Prakash-Karthik-Shreya-Ghoshal-Shekhinah-Shawn-Jazeel.mp3 -> song_b424e315967b.mp3
# Copied: Vizhiyil-Sonu-Nigam-Swetha.mp3 -> song_2e1f0be9b479.mp3
# Copied: Sunn-Raha-Hai-Male-Version-Ankit-Tiwari.mp3 -> song_e42cedad5f6b.mp3
# Copied: Anbe-Aaruyirae-Prashan-Sean-Navin-Raaj-Mathavan.mp3 -> song_17a87fc9359d.mp3
# Copied: Yaaro-Manathile-Harris-Jayaraj-Bombay-Jayashri-Krish.mp3 -> song_7a9ec66ca140.mp3
# Copied: Kaathadi-Anand-Kashinath-Sublahshini.mp3 -> song_325c20ae3f74.mp3
# Copied: Irukkiraai-G-V-Prakash-Harini.mp3 -> song_0b9bb49f40cc.mp3
# Copied: Aen-Enakku-Jayadev-Sangeetha-Rajeshwaran-Sheepa.mp3 -> song_602f208f60df.mp3
# Copied: En-Iniya-Pon-Nilave-Pon-From-Moodu-Pani-K-J-Yesudas.mp3 -> song_212f66ed9d4c.mp3
# Copied: Megham-Karukatha-From-Thiruchitrambalam-Dhanush-Anirudh-Ravichander.mp3 -> song_08d25ca059f8.mp3
# Copied: Konjum-Kili-Yuvan-Shankar-Raja-Velmurugan.mp3 -> song_b16f345dad19.mp3
# Copied: Vizhigalin-Aruginil-Ramesh-Vinayakam.mp3 -> song_16ca69d77f90.mp3
# Copied: Eno-Kangal-Yuvan-Shankar-Raja-Sadhana-Sargam.mp3 -> song_0e081e6855b0.mp3
# Copied: Mudher-Kanave-Bombay-Jayashri-Harish-Raghavendra-OS-Arun.mp3 -> song_9e36658981be.mp3
# Copied: Ding-Dong-Madhu-Balakrishnan-Madhushri.mp3 -> song_70c677a33f49.mp3
# Copied: Thenmozhi-From-Thiruchitrambalam-Santhosh-Narayanan-Anirudh-Ravichander.mp3 -> song_b4189b5c0eed.mp3
# Copied: Un-Per-Solla-From-Minsara-Kanna-Hariharan-Sujatha.mp3 -> song_b2fde2b9d53a.mp3
# Copied: Aval-Ulaghazhagi-Karthik.mp3 -> song_431bb42e3b38.mp3
# Copied: Marakkuma-Nenjam-From-Vendhu-Thanindhathu-Kaadu-AR-Rahman-Thamarai.mp3 -> song_cd66e741ddd6.mp3
# Copied: Ennai-Vittu-From-Love-Today-Yuvan-Shankar-Raja-Sid-Sriram.mp3 -> song_00090eaf0a41.mp3
# Copied: Ennai-Vittu-Yuvanshankar-Raja-Version-Yuvan-Shankar-Raja.mp3 -> song_4e4a157fec79.mp3
# Copied: Kaarkuzhal-Kadavaiye-Sriram-ParthasarathySanthosh-NarayananPradeep-Kumar.mp3 -> song_6a6eaa996d00.mp3
# Copied: Paakaadhae-Paakaadhae-D-Imman-Vijay-Yesudas-Pooja-AV.mp3 -> song_98644b6fe240.mp3
# Copied: Edho-Solla-From-Murungakkai-Chips-Dharan-Kumar-Sid-Sriram.mp3 -> song_f86ba558df8f.mp3
# Copied: Aye-Aye-Aye-Hiphop-Tamizha.mp3 -> song_e172a90972f8.mp3
# Copied: Kadhal-Kappal-Santhosh-Narayanan.mp3 -> song_c9f8d01e1cc6.mp3
# Copied: Kangal-Neeye-G-V-Prakash-Sithara-Krishnakumar-Thamarai.mp3 -> song_4ec6cd309f96.mp3
# Copied: Akkam-Pakkam-Sadhana-Sargam.mp3 -> song_6614babf7088.mp3
# Copied: June-Ponal-Krishh-Arun.mp3 -> song_57bb7a03c45f.mp3
# Copied: Onakkaaga-Poranthaenae-Justin-Prabhakaran-Balram-Sandhya-SP-Charan-Anu-Anand.mp3 -> song_d46913cad4df.mp3
# Copied: Apna-Bana-Le-Sachin-Jigar-Arijit-Singh-Amitabh-Bhattacharya.mp3 -> song_bdcd5213da42.mp3
# Copied: Melliname-Harish-Raghavendra.mp3 -> song_fa6d086c87a2.mp3
# Processing playlist: Feel good tamil songs
# Duplicate found: Engeyum-Kaadhal-Harris-Jayaraj-Aalaap-Raju-Devan-Ekambaram-Ranina-Reddy.mp3 (already exists as song_1a2a1ba9e0f2)
# Duplicate found: Neela-Vaanam-Priya-Hemesh-Kamal-Haasan.mp3 (already exists as song_ec98c687a690)
# Duplicate found: Kadhaippoma-From-Oh-My-Kadavule-Leon-James-Sid-Sriram.mp3 (already exists as song_239babaa5d6a)
# Duplicate found: Kani-Mozhiyae-Harris-Jayaraj-Karthik.mp3 (already exists as song_a32eebc098b8)
# Copied: Ilamai-Thirumbudhe-From-Petta-Anirudh-Ravichander.mp3 -> song_fe67d0c4a83f.mp3
# Duplicate found: Un-Vizhigalil-Anirudh-Ravichander-Shruti-Haasan.mp3 (already exists as song_3afbd2b96bc9)
# Copied: Moongil-Thottam-AR-Rahman-Abhay-Jodhpurkar-Harini.mp3 -> song_96c00a3e5817.mp3
# Duplicate found: Mudhal-Nee-Mudivum-Nee-Title-Track-From-Mudhal-Nee-Mudivum-Nee-Darbuka-Siva-Sid-Sriram.mp3 (already exists as song_6ee06b0c6605)
# Duplicate found: Oh-Penne-Anirudh-Ravichander-Vishal-Dadlani.mp3 (already exists as song_afd87a393b33)
# Copied: Unakkul-Naane-Pritt-dilushselva.mp3 -> song_3a4f926542c6.mp3
# Copied: Vaanam-Yuvan-Shankar-Raja.mp3 -> song_711366e67559.mp3
# Copied: Nenjae-Yezhu-AR-Rahman.mp3 -> song_d52cd4e98dc5.mp3
# Copied: Boomi-Enna-Suthudhe-Anirudh-Ravichander.mp3 -> song_a7f66f99bc28.mp3
# Duplicate found: Mannipaaya-AR-Rahman-Shreya-Ghoshal.mp3 (already exists as song_3edf6846cf1f)
# Duplicate found: Enna-Solla-Pogirai-Shankar-Mahadevan.mp3 (already exists as song_04decdd945ea)
# Duplicate found: Anbil-Avan-AR-Rahman-Chinmayi-Devan-Ekambaram.mp3 (already exists as song_1f536bba5b5a)
# Copied: Adada-Adada-Siddharth-Devi-Sri-Prasad.mp3 -> song_05959d51c2c1.mp3
# Duplicate found: The-Life-of-Ram-Govind-Vasantha-Pradeep-Kumar.mp3 (already exists as song_6981c94d29af)
# Duplicate found: Oh-Shanthi-Shanthi-Harris-Jayaraj-Clinton-SP-Charan.mp3 (already exists as song_3c00ef160f8c)
# Copied: Thangamey-Anirudh-Ravichander.mp3 -> song_b1eed02e084e.mp3
# Copied: Aga-Naga-From-Ponniyin-Selvan-Part-2-AR-Rahman-Shakthisree-Gopalan.mp3 -> song_dc9ee0a026a8.mp3
# Copied: Unnai-Kaanadhu-Naan-Shankar-Ehsaan-Loy-Kamal-Haasan-Shankar-Mahadevan.mp3 -> song_423dba911a2e.mp3
# Duplicate found: Kadhal-Kappal-Santhosh-Narayanan.mp3 (already exists as song_c9f8d01e1cc6)
# Duplicate found: Nallai-Allai-AR-Rahman-Chinmayi-Sathyaprakash.mp3 (already exists as song_fd749732f428)
# Duplicate found: Anbe-En-Anbe-Harris-Jayaraj-Harish-Raghavendra.mp3 (already exists as song_3e3eff8f2ba2)
# Duplicate found: Mazhai-Vara-Pogudhae-Harris-Jayaraj-Karthik-Emcee-Jesz.mp3 (already exists as song_8d5d404ba43a)
# Duplicate found: Yaaro-Manathile-Harris-Jayaraj-Bombay-Jayashri-Krish.mp3 (already exists as song_7a9ec66ca140)
# Duplicate found: Mundhinam-Harris-Jayaraj-Naresh-Iyer-Prashanthini.mp3 (already exists as song_e65353861716)
# Duplicate found: Kuru-Kuru-Sundar-Narayana-Rao.mp3 (already exists as song_78d088b0e467)
# Duplicate found: Nenjukkul-Peidhidum-Harris-Jayaraj-Hariharan-Devan-Ekambaram-VV-Prassanna.mp3 (already exists as song_a36025857866)
# Copied: Munbe-Vaa-AR-Rahman-Shreya-Ghoshal-Naresh-Iyer.mp3 -> song_3fc0d9790f6d.mp3
# Copied: Mun-Andhi-Harris-Jayaraj-Karthik-Megha.mp3 -> song_ece8ca569864.mp3
# Duplicate found: Marudaani-AR-Rahman-Madhushree-Hentry-Kuruvila.mp3 (already exists as song_866113083449)
# Copied: Avalukena-Anirudh-Ravichander-Srinidhi-Venkatesh.mp3 -> song_8963542b800a.mp3
# Copied: Paartha-Mudhal-Harris-Jayaraj-Bombay-Jayashri-Thamarai.mp3 -> song_64784f75cac9.mp3
# Copied: Nilaave-Vaa-S-P-Balasubrahmanyam.mp3 -> song_239712020976.mp3
# Duplicate found: June-Ponal-Krishh-Arun.mp3 (already exists as song_57bb7a03c45f)
# Duplicate found: Yennai-Maatrum-Kadhale-Anirudh-RavichanderSid-Sriram.mp3 (already exists as song_983ab50870c9)
# Copied: Loosu-Pennae-Yuvan-Shankar-Raja-Silambarasan-TR-Blaze.mp3 -> song_77d0e9d18461.mp3
# Copied: Yaanji-Anirudh-Ravichander-Sam-CS-Shakthisree-Gopalan.mp3 -> song_a774d170b279.mp3
# Duplicate found: High-On-Love-Yuvan-Shankar-RajaSid-Sriram.mp3 (already exists as song_e5592ce2dbe2)
# Duplicate found: Mental-Manadhil-AR-Rahman-Jonita-Gandhi.mp3 (already exists as song_c2f35f1007ed)
# Copied: Hayyoda-From-Jawan-Anirudh-Ravichander-Priya-Mali.mp3 -> song_dcaff2486630.mp3
# Copied: Naan-Gaali-From-Good-Night-Sean-Roldan-Mohan-Rajan.mp3 -> song_34af8085a53b.mp3
# Copied: Kannmoodi-thirakkum-Devi-Sri-Prasad.mp3 -> song_5b349a1987a9.mp3
# Copied: Ennavale-Adi-Ennavale-Unnikrishnan.mp3 -> song_b2a93384a6f6.mp3
# Copied: Konjam-Konjam-Vijay-Prakash.mp3 -> song_91f6d4894b6d.mp3
# Copied: Anbenum-From-Leo-Anirudh-Ravichander-Lothika.mp3 -> song_337519ed2b94.mp3
# Duplicate found: Yathe-Yathe-G-V-Prakash.mp3 (already exists as song_87e4a00d6cbe)
# Copied: Kangal-Irandal-James-Vasanthan-Bellie-Raj-Deepa-Miriam.mp3 -> song_8e121db38592.mp3
# Copied: Unna-Vida-Kamal-Haasan-Shreya-Ghoshal.mp3 -> song_e4429fccfed8.mp3
# Duplicate found: Azhage-Hiphop-Tamizha.mp3 (already exists as song_8895646af3c4)
# Copied: Unnaale-Unnaale-Karthik-Krish-Harini.mp3 -> song_5a42dd42baca.mp3
# Copied: Unakku-Thaan-Santhosh-Narayanan-Dhvani-Kailas.mp3 -> song_29a1608d44a9.mp3
# Duplicate found: Aye-Sinamika-AR-Rahman-Karthik.mp3 (already exists as song_3b56538d08cf)
# Duplicate found: Ondra-Renda-Bombay-Jayashri-Thamarai.mp3 (already exists as song_fe697801ac3d)
# Duplicate found: Orasaadha-Madras-Gig-Vivek-Mervin.mp3 (already exists as song_638c79eaae35)
# Duplicate found: Vaadi-Pulla-Vaadi-Hiphop-Tamizha.mp3 (already exists as song_2937d1e0634a)
# Duplicate found: Sakkarakatti-Hiphop-Tamizha.mp3 (already exists as song_8c382e86fdb0)
# Copied: Kadhal-Anukkal-Vijay-Prakash-Shreya-Ghosal.mp3 -> song_60de278c854b.mp3
# Copied: Kannalane-K-S-Chithra-AR-Rahman-Chorus.mp3 -> song_912971adcc92.mp3
# Copied: Azhagiye-AR-Rahman-Arjun-Chandy-Haricharan-Jonita-Gandhi.mp3 -> song_1fa3ae31923a.mp3
# Copied: Water-Packet-Santhosh-Narayanan-Shweta-Mohan-Gana-Kadhar.mp3 -> song_9797dcd5a723.mp3
# Copied: Aasa-Kooda-From-Think-Indie-Sai-Abhyankkar-Sai-Smriti.mp3 -> song_966faa9a3865.mp3
# Duplicate found: Sandakari-Neethan-From-Sangathamizhan-Vivek-Mervin-Anirudh-Ravichander-Jonita-Gandhi-Mervin-Solomon.mp3 (already exists as song_4925f27f8c31)
# Copied: Nee-Kobapattal-Devi-Sri-Prasad-Sagar-Pa-Vijay.mp3 -> song_39cdeaa13357.mp3
# Copied: Lolita-Harris-Jayaraj-Karthik-Prashanthini.mp3 -> song_881e94ad7037.mp3
# Copied: Katchi-Sera-From-Think-Indie-Sai-Abhyankkar.mp3 -> song_be48bc2b9b1a.mp3
# Duplicate found: Idhazhin-Oram-The-Innocence-of-Love-Anirudh-Ravichander-Ajesh.mp3 (already exists as song_f904bcb561f8)
# Duplicate found: Ennai-Konjum-Timmy-Tippu-Pop-Shalini-Thamarai.mp3 (already exists as song_14d1d3410348)
# Copied: Asku-Laska-Chinmayi-Vijay-Prakash.mp3 -> song_32746e4752c9.mp3
# Copied: Chillanjirukkiye-From-Lubber-Pandhu-Sean-Roldan-Pradeep-Kumar-Sivaangi-Krishnakumar.mp3 -> song_c0e3b72c4c91.mp3
# Copied: Endi-Ippadi-Santhosh-Narayanan.mp3 -> song_d3cd670bfd72.mp3
# Copied: Neethanae-From-Mersal-AR-Rahman-Shreya-Ghoshal.mp3 -> song_d15d65482bad.mp3
# Copied: Nillayo-Haricharan.mp3 -> song_c2e97c7fabfc.mp3
# Copied: Vazhithunaiye-Leon-James-Sid-Sriram-Sanjana-Kalmanje-Vignesh-Shivan.mp3 -> song_810e9c65b80b.mp3
# Duplicate found: Maya-Nadhi-Santhosh-Narayanan-Ananthu-Pradeep-Kumar-Shweta-Mohan.mp3 (already exists as song_4931ae62cad3)
# Copied: Thanga-Sela-Shankar-Mahadevan-Pradeep-Kumar-Ananthu-Santhosh-Narayanan-Arunraja-Kamaraj.mp3 -> song_c6ef136dd036.mp3
# Processing playlist: Feel it
# Copied: Kaadhal-Vaithu-Yuvan-Shankar-Raja-Vijay-Yesudas.mp3 -> song_1d90f34a7aeb.mp3
# Copied: Pogadhe-Yuvan-Shankar-Raja.mp3 -> song_4c75a7bb9c10.mp3
# Copied: Oru-Naalil-Yuvan-Shankar-Raja.mp3 -> song_7f5bf99396f9.mp3
# Duplicate found: Minnalea-En-Vazhvin-S-P-Balasubrahmanyam.mp3 (already exists as song_4256c34a88d6)
# Duplicate found: Malare-Vidyasagar-S-P-Balasubrahmanyam-S-Janaki.mp3 (already exists as song_58cd27cac120)
# Copied: Pesugiraen-Yuvan-Shankar-Raja-Neha-Bhasin.mp3 -> song_365a0ffa0714.mp3
# Copied: Aaruyire-AR-Rahman-Chinmayi-Murtuza-Khan-Qadir-Khan.mp3 -> song_37714f5cf83c.mp3
# Copied: Minnalgal-Koothadum-From-Polladhavan-G-V-Prakash-NaMuthukumar-Karthik-Bombay-Jeyashree.mp3 -> song_a1a540315b5b.mp3
# Duplicate found: Enna-Naan-Seiven-Pradeep-Kumar-Kalyani-Nair.mp3 (already exists as song_15b4aeda9d99)
# Copied: Thaniye-From-Vidaamuyarchi-Anirudh-Ravichander.mp3 -> song_fd650abd87ac.mp3
# Duplicate found: Naane-Varugiraen-AR-Rahman-Shashaa-Tirupati-Sathyaprakash.mp3 (already exists as song_5e4fe0b7cafd)
# Copied: Thaensudare-From-Lover-Sean-Roldan-Shakthisree-Gopalan.mp3 -> song_42e962d8d351.mp3
# Duplicate found: Nenjukkule-AR-Rahman-Shakthisree-Gopalan.mp3 (already exists as song_90e8b4b805b1)
# ...
# Copied: Vaa-Vaa-En-Thalaivaa-Unnikrishnan-Harini-Mahadhi-Shobana.mp3 -> song_5c081d643fb0.mp3
# Copied: Thodu-Thoduveneve-Language-Tamil-Film-Thullatha-Manamum-Thullum-Film-Artist-1-Vijay-Film-Artist-2-Si.mp3 -> song_c1f77880d263.mp3
# Copied: Mallikaiye-Mallikaiye-K-S-Chithra-Anuradha-Sriram.mp3 -> song_fba23c518bc1.mp3
# Copied: Ennai-Pada-Vaitha-Hariharan.mp3 -> song_b417d4766f57.mp3
# Copied: Kathukku-Pookkal-Sirpy-Hariharan-Sujatha-Pa-Vijay.mp3 -> song_8bba17597e95.mp3
# Copied: Malligai-Poove-Sujatha-Unnikrishnan.mp3 -> song_280f75f7d53d.mp3
# Copied: Penn-Kiliye-Penn-Kiliye-Unnikrishnan-Sujatha.mp3 -> song_930504a1707b.mp3
# Copied: Enakkoru-Snehidhi-SA-Rajkumar-Hariharan-Mahalakshmi-Iyer.mp3 -> song_7a82cc177389.mp3
# Copied: Puyalae-Puyalae-From-Kovil-Karthik-Mahathi.mp3 -> song_d183ccd457db.mp3
# Copied: Pudhu-Malar-Thottu-Sriram-Parthasarathy-Vairamuthu.mp3 -> song_beba969eebba.mp3
# Copied: Rahathulla-Chandralekha-Annupamaa.mp3 -> song_1451b38099d8.mp3
# Copied: Edhu-Enna-From-Sivakasi-Harish-Raghavendra-Umaraman.mp3 -> song_8111ae644874.mp3
# Copied: Manjakkaattu-Maina-Karthik-Sadhana-Sargam.mp3 -> song_2c99947645df.mp3
# Copied: Rosave-SA-Rajkumar-Unnikrishnan.mp3 -> song_76ad1c71b040.mp3
# Copied: Anandha-Roja-SA-Rajkumar-Unnikrishnan-Sujatha.mp3 -> song_66c5dcf10807.mp3
# Copied: Yeppadi-Irruntha-Tippu-Gopika-Poornima-Viveka.mp3 -> song_7edb7aa77ec4.mp3
# Duplicate found: Idhu-Varai-Yuvan-Shankar-Raja-Ajesh-Andrea-Jeremiah.mp3 (already exists as song_c42b7fe787ef)
# Copied: Mazhai-Thulli-Hariharan-M-S-Viswanathan.mp3 -> song_6277a266ad08.mp3
# Copied: Kan-Pesum-Varthaigal-From-7G-Rainbow-Colony-Karthik.mp3 -> song_3285d98c25c9.mp3
# Copied: Parthu-Parthu-Male-Vocals-S-P-Balasubrahmanyam-SA-Rajkumar-Pa-Vijay.mp3 -> song_c4db079b0bc1.mp3
# Copied: Oru-Devathai-Vanthu-Vittaal-Male-Vocals-Hariharan-SA-Rajkumar-R-Ravishankar.mp3 -> song_969a96e3908b.mp3
# Copied: Enge-En-Punnagail-From-Thaalam-S-P-Balasubrahmanyam-Shoba.mp3 -> song_ea6b0eaac351.mp3
# Copied: Innisai-Paadivarum-Language-Tamil-Film-Thullatha-Manamum-Thullum-Film-Artist-1-Vijay-Film-Artist-2-S.mp3 -> song_b84cbbd78752.mp3
# Copied: Kumudhampol-Sirpy-Hariharan-A-Thavasimani.mp3 -> song_48943b4be858.mp3
# Duplicate found: Malai-Mangum-Neram-Ranina-Reddy.mp3 (already exists as song_527c6fec825c)
# Copied: Vachukka-Solli-From-Jai-Surya-Karthik-Febi-Mani.mp3 -> song_09b555c1abe3.mp3
# Copied: Mannile-Devi-Sri-Prasad-SP-Charan-Sumangaly.mp3 -> song_d539ae80a585.mp3
# Copied: Kanaa-Kandenadi-From-Parthipan-Kanavu-Madhu-Balakrishnan.mp3 -> song_78d3437995c3.mp3
# Copied: Sollitharavaa-Madhu-Balakrishnan-Sadhana-Sargam.mp3 -> song_4b4506270a47.mp3
# Copied: Senthamizh-Nattu-Thamizhachiea-From-Vandicholai-Chinnarasu-Shaghul-Hameeth.mp3 -> song_fbcbab8328de.mp3
# Copied: Secret-of-Success-AR-Rahman-Lucky-Ali-Blaaze-Vasundhara-Das.mp3 -> song_40041d254266.mp3
# Duplicate found: Adiyae-Azhagae-From-Oru-Naal-Koothu-Justin-Prabhakaran.mp3 (already exists as song_cef232a492bc)
# Copied: Vachikka-vachikka-KK-Srilekha-Parthasarathy.mp3 -> song_f4e55353a64b.mp3
# Copied: Kannukkul-Yedho-Vijay-Yesudas-Rita-Thyagarajan.mp3 -> song_e1ddf3849ca9.mp3
# Copied: Manasellam-Mazhaiye-Sonu-Nigam-Saindhavi-G-V-Prakash-NaMuthukumar.mp3 -> song_6c8e1b3a1d4f.mp3
# Copied: Snehidhane-Pt-1-Sadhana-Sargam-Srinivas.mp3 -> song_63e2fd68dfe7.mp3
# Duplicate found: Manasula-Soora-Kaathey-Santhosh-Narayanan-Sean-Roldan-Divya-Ramani.mp3 (already exists as song_e412a8cfa5d9)
# Copied: Poopol-Poopol-Harris-Jayaraj-Tippu-Karthik.mp3 -> song_6ea9258a7a81.mp3
# Duplicate found: Saayndhu-Saayndhu-Ilaiyaraaja-Yuvan-Shankar-Raja-Ramya-NSK.mp3 (already exists as song_2ba3e9809030)
# Copied: Kadavul-Thandha-SP-Charan-Kalpana-Patowary.mp3 -> song_0eb325fbfcf8.mp3
# Copied: Rangu-Rangamma-From-Bheema-Vijay-Yesudas-Kailash-Kher-Swarnalatha.mp3 -> song_081d48981ef0.mp3
# Copied: Arali-Vidhaiyil-From-Kovil-Sriram.mp3 -> song_89f0c7f4a7f2.mp3
# Copied: Parthen-Rasithen-Yugendran-Reshmi.mp3 -> song_d3acec07d0f8.mp3
# Copied: Verenna-Ivan-Yaro-Unnikrishnan-Harini.mp3 -> song_db1643c0987f.mp3
# Copied: Theradi-Veeethiyil-Devathai-From-Run-Manikka-Vinayagam-Karthik.mp3 -> song_de66a687b60f.mp3
# Copied: Azhage-Bhramanidam-From-Devathayai-Kanden-Harish-RaghavendraChinmayi-Sripaada.mp3 -> song_abd8507334a7.mp3
# Copied: Ennai-Konjam-Vidyasagar-Hariharan-Sujatha.mp3 -> song_cc33bd57a938.mp3
# Copied: Oru-Mani-Adithaal-Hariharan.mp3 -> song_b6b094f32fd9.mp3
# Copied: Manam-Virumbuthey-From-Naerukku-Naer-Unnikrishnan.mp3 -> song_2856f1f4690c.mp3
# Copied: Enna-Nenatche-From-Chokkathangam-Anuradha-Sriram-Unnikrishnan.mp3 -> song_38776e83bc0a.mp3
# Duplicate found: Malare-Vidyasagar-S-P-Balasubrahmanyam-S-Janaki.mp3 (already exists as song_58cd27cac120)
# Copied: Yaaradu-Karthik-Suchithra.mp3 -> song_25ff1b5b8755.mp3
# Copied: Gnapagam-Varuthae-Language-Tamil-Film-Autograph-Film-Artists-Cheran-Gopika-Bharadwaj.mp3 -> song_f5bdc221c262.mp3
# Copied: Kaalamellam-Kadhal-Unnikrishnan-K-S-Chithra.mp3 -> song_6e652970a90e.mp3
# Copied: Kavalai-Padathey-Deva.mp3 -> song_2540b76e6d61.mp3
# Copied: Meenatchi-Meenatchi-Deva-Sabesh.mp3 -> song_0e4edf7ed812.mp3
# Copied: Sathikadi-From-Sukran-Sangeetha-Mahadevan-Vijay-Antony.mp3 -> song_e4dfe14f6961.mp3
# Copied: Varaaga-Nathi-AR-Rahman.mp3 -> song_688ef23c61a0.mp3
# Copied: Aasai-Aasai-From-Dhol-Shankar-Mahadevan-Sujatha.mp3 -> song_5258b1831289.mp3
# Copied: Anjathey-Jeeva-Sirkazhi-G-Sivachidambaram-Swarnalatha-Vairamuthu.mp3 -> song_21572c54665b.mp3
# Duplicate found: En-Anbay-Shankar-Mahadevan.mp3 (already exists as song_1a97bf58c0f0)
# Copied: Mandram-Vandha-S-P-Balasubrahmanyam.mp3 -> song_424f4675e1fc.mp3
# Copied: Yaar-Indha-Saalai-Oram-From-Thalaivaa-G-V-Prakash-Saindhavi.mp3 -> song_b28941ee50f5.mp3
# Duplicate found: Mun-Paniya-From-Nandhaa-S-P-Balasubrahmanyam-Malgudi-Subha.mp3 (already exists as song_bba332cbc79d)
# Copied: Kangal-Neeye-Sithara-Krishnakumar.mp3 -> song_726c903c73b3.mp3
# Copied: Dhaandiya-Aatamum-AR-Rahman-Unni-Menon-Kavita-Krishnamurthy.mp3 -> song_29639b061488.mp3
# Copied: Thanga-Thamari-Magale-From-Minsara-Kanavu-S-P-Balasubrahmanyam.mp3 -> song_5ff5aa02b737.mp3
# Copied: Kambathu-Ponnu-Yuvan-Shankar-Raja.mp3 -> song_a2fa4c70339c.mp3
# Copied: Kannan-Varum-Velai-Anuradha-Sriram-Madhushree.mp3 -> song_072ee2ea684e.mp3
# Copied: Enjoy-Enjaami-Dhee-Arivu-Santhosh-Narayanan.mp3 -> song_14a112806869.mp3
# Duplicate found: Kanne-Kanne-Madras-Gig-Leon-James-Jonita-Gandhi.mp3 (already exists as song_d0fb39333ab3)
# Copied: Jingu-Chikka-From-Mynaa-Solar-Sai-Kalpana-Patowary.mp3 -> song_e0975a3480e7.mp3
# Copied: Kadalenum-From-Kadhalar-Dhinam-S-P-Balasubrahmanyam-Swarnalatha.mp3 -> song_712bfa79c49b.mp3
# Copied: Soora-Thenga-Vidyasagar-Tippu.mp3 -> song_6eca8904d99d.mp3
# Copied: Yaar-Azhaippadhu-From-Maara-Ghibran-Sid-Sriram.mp3 -> song_775edeaafa0b.mp3
# Copied: Asku-Maaro-Dharan-Kumar-Sivaangi-Krishnakumar.mp3 -> song_d69612cd128b.mp3
# Copied: Jai-Sulthan-From-Sulthan-Vivek-Mervin-Anirudh-Ravichander-Junior-Nithya-Gana-Guna.mp3 -> song_e28b6e8fac2b.mp3
# Copied: Kadhal-Sadugudu-SP-Charan.mp3 -> song_5d8d28c4c563.mp3
# Duplicate found: THENDRAL-VANTHU-Unplugged-Sabari-Darshan-Deepak-Chander.mp3 (already exists as song_885a7c4e33e7)
# Copied: Otha-Sollaala-G-V-Prakash-Velmurugan.mp3 -> song_c28f04d35406.mp3
# Copied: Kasu-Panam-From-Soodhu-Kavvum-Gana-Bala-Anthony-Daasan.mp3 -> song_2b03c2180386.mp3
# Copied: Adada-Mazhaida-From-Paiya-Yuvan-Shankar-Raja-Rahul-Nambiar-Saindhavi.mp3 -> song_f97d5084f309.mp3
# Duplicate found: Yathe-Yathe-G-V-Prakash.mp3 (already exists as song_87e4a00d6cbe)
# Duplicate found: Adiyae-Kolluthey-Harris-Jayaraj-Krishh-Benny-Dayal-Shruti-Haasan.mp3 (already exists as song_3904517e6407)
# Duplicate found: Nenjukkul-Peidhidum-Harris-Jayaraj-Hariharan-Devan-Ekambaram-VV-Prassanna.mp3 (already exists as song_a36025857866)
# Duplicate found: Vaarayo-Vaarayo-Harris-Jayaraj-Chinmayi-Unnikrishnan-Mega.mp3 (already exists as song_5f0b8b294e0a)
# Duplicate found: Innum-Konjam-Naeram-AR-Rahman-Vijay-Prakash-Shweta-Mohan.mp3 (already exists as song_893141da3260)
# Duplicate found: Kangal-Irandal-James-Vasanthan-Bellie-Raj-Deepa-Miriam.mp3 (already exists as song_8e121db38592)
# Duplicate found: Enkeyoo-Partha-Yuvan-Shankar-Raja-Udit-Narayan.mp3 (already exists as song_74c922cf261d)
# Copied: Vanna-Nilave-Hariharan.mp3 -> song_5ce55e3d8606.mp3
# Copied: Something-Something-Tippu-Pa-Vijay.mp3 -> song_8c79552f525f.mp3
# Copied: Paakatha-Devi-Sri-Prasad-Tippu-Sumangaly.mp3 -> song_98860523cc19.mp3
# Copied: Kokkarakko-Vidyasagar-Udit-Narayan-Sujatha.mp3 -> song_1614d2fd497e.mp3
# Copied: Aagaayam-S-P-Balasubrahmanyam-NaMuthukumar.mp3 -> song_51df6fe3484d.mp3
# Copied: Ichu-Ichu-Vijay-Antony-Sangeetha-Rajeshwaran.mp3 -> song_4b158dc6f1a0.mp3
# Copied: Dole-Dole-Than-Mani-Sharma.mp3 -> song_cc71887aca9e.mp3
# Duplicate found: Dailamo-Dailamo-Vijay-Antony-Sangeetha-Rajeshwaran.mp3 (already exists as song_895fc1a49e45)
# Copied: Palaanadhu-Palaanadhu-Vidyasagar-Rajalakshmi.mp3 -> song_bcaf1a1c2a21.mp3
# Copied: Dheemthanakka-Thillana-Devi-Sri-Prasad.mp3 -> song_3cab7739c9c0.mp3
# Copied: Kozhi-Veda-Kozhi-Naveen-Priya-Viveka.mp3 -> song_d2f5a8b425f7.mp3
# Copied: Uchimandai-Vijay-Antony-Krishna-Iyer-Shoba-Chandrasekhar-Charulatha-Mani-Shakthisree-Gopalan.mp3 -> song_59726e393626.mp3
# Copied: Hey-Vaada-Vaada-MLR-Karthikeyan-Anitha-Karthikeyan.mp3 -> song_ce455af43452.mp3
# Copied: Ithu-thana-From-Saamy-K-S-Chithra.mp3 -> song_c1e1a415f8c6.mp3
# Copied: Anbae-Anbae-Hariharan-Anuradha-Sriram-Vairamuthu.mp3 -> song_4f7142ff2224.mp3
# Copied: Vaada-Mapilley-Devi-Sri-Prasad.mp3 -> song_5867813b732f.mp3
# Duplicate found: Chinna-Thamarai-Vijay-Antony-Krishh-Suchitra.mp3 (already exists as song_a7031cdbdc17)
# Copied: Shakalakka-Baby-From-Mudhalvan-Vasundhara-Das-Pravin-Mani.mp3 -> song_90a41d86d9a4.mp3
# Copied: Idicha-Pacharasi-Vijay-Antony-Ranjith-Govind-Sangeetha-Vinaya.mp3 -> song_b549b2872da3.mp3
# Copied: Aasai-Dosai-Priya-Subramani.mp3 -> song_8058acd048e3.mp3
# Copied: Rangola-Shankar-Mahadevan-Sujatha.mp3 -> song_f9886caf6a31.mp3
# Duplicate found: Machaan-Machaan-From-Silambattam-Yuvan-Shankar-Raja-Ilaiyaraaja-Bela-Shende.mp3 (already exists as song_fc417715ac65)
# Copied: Ammadi-Aathadi-Silambarasan-TR-T-Rajendar-Suchitra-Mahathi.mp3 -> song_c6acea94efb8.mp3
# Copied: Nee-Kobapattal-Devi-Sri-Prasad.mp3 -> song_011bb5da59f1.mp3
# Copied: Othaiyadi-Pathayila-Dhibu-Ninan-Thomas-Anirudh-Ravichander.mp3 -> song_e5615a86b31a.mp3
# Copied: Yenna-Solla-Pore-Devi-Sri-Prasad-MLR-Karthikeyan.mp3 -> song_78fa1c33c693.mp3
# Processing playlist: Top hits
# Copied: Monica-From-Coolie-Tamil-Anirudh-Ravichander-Sublahshini-Asal-Kolaar-Vishnu-Edavan.mp3 -> song_e30f77091cf5.mp3
# Copied: Kannadi-Poove-From-Retro-Santhosh-Narayanan-Vivek.mp3 -> song_d30c8c56c2eb.mp3
# Copied: Muththa-Mazhai-AR-Rahman-Dhee-Siva-Ananth.mp3 -> song_875db52edc6f.mp3
# Copied: Yedi-From-Nilavuku-En-Mel-Ennadi-Kobam-G-V-Prakash-Vivek-Dhanush-Jonita-Gandhi.mp3 -> song_cc7db8af7031.mp3
# Copied: Kanimaa-From-Retro-Santhosh-Narayanan-The-Indian-Choral-Ensemble-Vivek.mp3 -> song_01bd550e0cad.mp3
# Duplicate found: Vazhithunaiye-Leon-James-Sid-Sriram-Sanjana-Kalmanje-Vignesh-Shivan.mp3 (already exists as song_810e9c65b80b)
# Copied: Jinguchaa-From-Thug-Life-Tamil-AR-Rahman-Kamal-Haasan-Vaishali-Samant-Shakthisree-Gopalan-Adithya-RK.mp3 -> song_23b1e2d26426.mp3
# Copied: Og-Sambavam-From-Good-Bad-Ugly-G-V-Prakash-Adhik-Ravi-Chandran-Vishnu-Edavan.mp3 -> song_9acf3e6f1dfe.mp3
# Copied: Sawadeeka-From-Vidaamuyarchi-Anirudh-Ravichander-Anthony-Daasan-Arivu.mp3 -> song_eeca48417072.mp3
# Copied: Nee-Singam-Dhan-AR-Rahman-Sid-Sriram.mp3 -> song_e9d041db240b.mp3
# Copied: Golden-Sparrow-From-Nilavuku-En-Mel-Ennadi-Kobam-G-V-Prakash-Arivu-Dhanush-Sublahshini.mp3 -> song_e5acc5689c49.mp3
# Copied: Vinveli-Nayaga-AR-Rahman-Shruti-Haasan-A-R-Ameen-Karthik-Netha-Prashanth-Venkat.mp3 -> song_c88ac2fa03c6.mp3
# Copied: Ak-The-Tiger-Darkkey-G-V-Prakash.mp3 -> song_65bee03450be.mp3
# Copied: Vennilavu-Saaral-G-V-Prakash-Kapil-Kapilan-Rakshita-Suresh-Yugabharathi.mp3 -> song_d1469d887b3b.mp3
# Copied: Hey-Minnale-From-Amaran-Tamil-G-V-Prakash-Haricharan-Shweta-Mohan-Karthik-Netha.mp3 -> song_157a69d60275.mp3
# Duplicate found: Aasa-Kooda-From-Think-Indie-Sai-Abhyankkar-Sai-Smriti.mp3 (already exists as song_966faa9a3865)
# Copied: Rise-Of-Dragon-Leon-James-Anirudh-Ravichander-Nadisha-Thomas-El-Fé-Choir-Vignesh-Shivan.mp3 -> song_3a14989c83df.mp3
# Copied: God-Bless-U-From-Good-Bad-Ugly-Anirudh-Ravichander-Paal-Dabba-G-V-Prakash-Rokesh.mp3 -> song_5c361c51586c.mp3
# Copied: Sithira-Puthiri-From-Think-Indie-Sai-Abhyankkar-Vivek.mp3 -> song_f8264a4082bf.mp3
# Copied: Paiya-Dei-From-Think-Indie-Asal-Kolaar-Anand-Kashinath.mp3 -> song_f9912c95b030.mp3
# Copied: Manasilaayo-From-Vettaiyan-Anirudh-Ravichander-Malaysia-Vasudevan-Deepthi-Suresh-Yugendran-Vasudeva-.mp3 -> song_3547eeffb263.mp3
# Copied: Chillanjirukkiye-Sean-Roldan-Pradeep-Kumar-Sivaangi-Krishnakumar.mp3 -> song_58ce55abac75.mp3
# Copied: Water-Packet-From-Raayan-AR-Rahman-Santhosh-Narayanan-Shweta-Mohan-Gana-Kadhar.mp3 -> song_180c19a85df2.mp3
# Copied: Achacho-From-Aranmanai-4-Hiphop-Tamizha-Kharesma-Ravichandran-Srinisha-Jayaseelan.mp3 -> song_df50686106e4.mp3
# Copied: Matta-Yuvan-Shankar-Raja-Shenbagaraj-Velu-Sam-Narayanan-Ravishankar.mp3 -> song_14c8d6015148.mp3
# Copied: Beer-Song-From-Diesel-Dhibu-Ninan-Thomas-Gana-Guna-Rokesh.mp3 -> song_defedff38cd5.mp3
# Copied: Minikki-Minikki-G-V-Prakash-Sinduri-Vishal-Uma-Devi.mp3 -> song_8dd5036e7303.mp3
# Copied: Kaathu-Mela-From-Think-Indie-Paal-Dabba-ofRO-Deva.mp3 -> song_bf1854a42a9c.mp3
# Copied: Yennai-Izhukkuthadi-From-Kadhalikka-Neramillai-AR-Rahman-Dhee.mp3 -> song_464d53e3bbd2.mp3
# Copied: Whistle-Podu-From-The-Greatest-Of-All-Time-Thalapathy-Vijay-Yuvan-Shankar-Raja-Madan-Karky.mp3 -> song_47496f1ffa50.mp3
# Copied: Adangaatha-Asuran-AR-Rahman-Dhanush.mp3 -> song_4c45b1ed6b81.mp3
# Copied: Maamadura-From-Jigarthanda-DoubleX-Santhosh-Narayanan-Dhee-Vivek.mp3 -> song_016fc6b8ccc0.mp3
# Duplicate found: Katchi-Sera-From-Think-Indie-Sai-Abhyankkar.mp3 (already exists as song_be48bc2b9b1a)
# Copied: Spark-From-The-Greatest-Of-All-Time-Yuvan-Shankar-Raja-Vrusha-Balu.mp3 -> song_2346a1e73e47.mp3
# Copied: Badass-From-Leo-Anirudh-Ravichander.mp3 -> song_db3ca96c62c9.mp3
# Copied: Makkamishi-From-Brother-Harris-Jayaraj-Paal-Dabba-Dacalty.mp3 -> song_287603f5706d.mp3
# Copied: Nenjin-Ezhuth-Adarsh-Krishnan-N-Vidya-Lakshmi-G.mp3 -> song_c99011ccfc34.mp3
# Copied: En-Rojaa-Neeye-Hesham-Abdul-Wahab.mp3 -> song_81f376ed5a62.mp3
# Copied: Kaavaalaa-From-Jailer-Anirudh-Ravichander-Shilpa-Rao-Arunraja-Kamaraj.mp3 -> song_1b26154c541a.mp3
# Copied: Railin-Oligal-From-Blue-Star-Govind-Vasantha-Pradeep-Kumar-Shakthisree-Gopalan.mp3 -> song_e6277f168d82.mp3
# Duplicate found: Unakku-Thaan-Santhosh-Narayanan-Dhvani-Kailas.mp3 (already exists as song_29a1608d44a9)
# Copied: Mainaru-Vetti-Katti-Santhosh-Narayanan-Anirudh-Ravichander-Dhee.mp3 -> song_e1b70d27aa73.mp3
# Copied: Ordinary-Person-From-Leo-Anirudh-Ravichander-Nikhita-Gandhi.mp3 -> song_a6127bcdc4e6.mp3
# Copied: Hukum-Thalaivar-Alappara-Anirudh-Ravichander-Super-Subu.mp3 -> song_05bbb8404e4d.mp3
# Copied: Naa-Ready-From-Leo-Anirudh-Ravichander-Vijay-Asal-Kolaar.mp3 -> song_32104c1f8b59.mp3
# Duplicate found: Vaa-Vaathi-G-V-Prakash-Shweta-Mohan.mp3 (already exists as song_214b7883152a)
# Copied: Jujubee-Anirudh-Ravichander-Dhee-Ananthakrrishnan-Super-Subu.mp3 -> song_e3c212be42a4.mp3
# Copied: Ranjithame-From-Varisu-Thalapathy-Vijay-MMManasi-Thaman-S.mp3 -> song_086a1f723704.mp3
# Copied: Jimikki-Ponnu-Thaman-S-Anirudh-Ravichander-Jonita-Gandhi.mp3 -> song_80100d024751.mp3
# Copied: Mehabooba-Ananya-Bhat.mp3 -> song_f4daf05d1d2f.mp3
#
# ==================================================
# CONSOLIDATION COMPLETE
# ==================================================
# Total unique songs: 1449
# Total playlists processed: 9
# Songs saved to: consolidated_music\songs
# Metadata saved to: consolidated_music\metadata
# Duplicates avoided: 254
#
# Generated files:
# - songs_database.json (complete song information)
# - playlists_database.json (playlist information with song lists)
# - song_playlist_mapping.json (song to playlist relationships)
